# %% [markdown]
# ## Part 2
# #### Load training file and create dictionary containing the occurrences of each annotation in the training set

# %%
def load_original_train():
    with open("train", encoding="utf-8") as file:
        train_list = file.readlines()
        train_list = [x.strip() for x in train_list]
        return train_list
    
train_list = load_original_train()

# %%
annotationDict = {"O": 0, "I-positive": 0, "B-positive": 0, "I-negative":0, "B-negative": 0, "I-neutral":0, "B-neutral":0}

for i in range(len(train_list)):
    annotated_word = train_list[i]
    each_word = annotated_word.split(" ")
    if (len(each_word) == 2):
        if each_word[1] == "O":
            annotationDict["O"] += 1
        elif each_word[1] == "I-positive":
            annotationDict["I-positive"] += 1
        elif each_word[1] == "B-positive":
            annotationDict["B-positive"] += 1
        elif each_word[1] == "I-negative":
            annotationDict["I-negative"] += 1
        elif each_word[1] == "B-negative":
            annotationDict["B-negative"] += 1
        elif each_word[1] == "I-neutral":
            annotationDict["I-neutral"] += 1
        elif each_word[1] == "B-neutral":
            annotationDict["B-neutral"] += 1

print(annotationDict)
# Out:
# {'O': 24714, 'I-positive': 227, 'B-positive': 809, 'I-negative': 236, 'B-negative': 705, 'I-neutral': 44, 'B-neutral': 119}

# %% [markdown]
# #### (a) Write a function that estimates the emission parameters from the training set using MLE

# %%
def estimate_emission(word, tag):
    countTop = 0
    countBottom = annotationDict[tag]
    for i in range(len(train_list)):
        annotated_word = train_list[i]
        each_word = annotated_word.split(" ")
        if len(each_word) == 2:
            if (each_word[0] == word and each_word[1] == tag):
                countTop += 1

#         print(countTop)
#         print(countBottom)
    return countTop/countBottom

estimate_emission("service", "O")
# Out:
# 0.00012138868657441127

# %% [markdown]
# #### (b) Replace the words that appear less than k times in the training set with a special token #UNK# before training. This leads to a “modified training set”.

# %%
import datetime

def modify_trainingset(k):
        wordCountDict = {}
        for i in range(len(train_list)):
            annotated_word = train_list[i]
            each_word = annotated_word.split(" ")
            if each_word[0] in wordCountDict:
                wordCountDict[each_word[0]] += 1
            else:
                wordCountDict[each_word[0]] = 1
        
       
        wordToBeReplacedDict = {}
        wordToBeReplacedList = []
        for key in wordCountDict:
            if wordCountDict[key] < k:
                wordToBeReplacedList.append(key)

        start = datetime.datetime.now()
        for i in range(len(train_list)): 
            annotated_word = train_list[i]
            each_word = annotated_word.split(" ")
            if each_word[0] in wordToBeReplacedList:
                train_list[i] = "#UNK# " + each_word[1]


        modifiedTotalTrainSet = "\n".join(train_list)

        f = open("modified_train","w+")
        f.write(modifiedTotalTrainSet)
                            
        end = datetime.datetime.now()
        elapsed = end - start
        print(elapsed)

modify_trainingset(3)
# Out:
# 0:00:01.371940

# %% [markdown]
# #### Loads the modified training set into a list, and count the occurences of each word in the list and store it into a dictionary called modifiedWordDict

# %%
def load_modified_train_file():
    with open("modified_train", encoding="utf-8") as file:
        modified_train_list = file.readlines()
        modified_train_list = [x.strip() for x in modified_train_list]
        return modified_train_list
        
modified_train_list = load_modified_train_file()

# %%
def get_word_dict():
    modifiedWordDict = {}        
    for i in range(len(modified_train_list)):
        annotated_word = modified_train_list[i]
        each_word = annotated_word.split(" ")
        if each_word[0] in modifiedWordDict:
            modifiedWordDict[each_word[0]] += 1
        else:
            modifiedWordDict[each_word[0]] = 1

    return modifiedWordDict
    
modifiedWordDict = get_word_dict()

# %%
def count_word_tag_pair_dict():
    word_tag_pair_dict= {}
    for word_tag_pair in modified_train_list:
        if word_tag_pair_dict.get(word_tag_pair) == None:
            word_tag_pair_dict[word_tag_pair] = 1
        else:
            word_tag_pair_dict[word_tag_pair] += 1
    return word_tag_pair_dict

    
wordTagPairDict = count_word_tag_pair_dict()

# %% [markdown]
# #### Implement a fixed emission function

# %%
def estimate_emission_fix(word, tag):
        countTop = 0
        countBottom = annotationDict[tag]
        if word in modifiedWordDict:
            # do nothing
            word = word
            
        else:
            word = "#UNK#"

        for i in range(len(modified_train_list)):
            annotated_word = modified_train_list[i]
            each_word = annotated_word.split(" ")
            if (each_word[0] == word and each_word[1] == tag):
                countTop += 1
        return countTop/countBottom

estimate_emission_fix("I", "O")
# Out:
# 0.14081087642631707

# %% [markdown]
# #### Loop through the words once and store the emission value of each word tag pair into a giant dictionary called giantEmissionDict

# %%
def store_estimate_emission_fix():
    giantEmissionDict = {}
    for word_tag_pair in modified_train_list:
        if word_tag_pair != "":
            word_tag_pair_list = word_tag_pair.split(" ")
            countTop = wordTagPairDict[word_tag_pair]
            countBottom = annotationDict[word_tag_pair_list[1]]
            emission = countTop/countBottom
            if giantEmissionDict.get(word_tag_pair) == None:
                giantEmissionDict[word_tag_pair] = countTop/countBottom
    return giantEmissionDict
    
giantEmissionDict = store_estimate_emission_fix()
print(giantEmissionDict)
# Out:
# {'Et O': 0.0011734239702193088, 'pour O': 0.011127296269321033, '#UNK# O': 0.14081087642631707, 'le O': 0.01885570931455855, 'tout O': 0.003641660597232338, 'la O': 0.01962450432952982, 'musique B-negative': 0.005673758865248227, 'très O': 0.010075260985676135, 'de O': 0.030670874807801247, 'toute O': 0.00024277737314882253, 'conversation O': 0.00012138868657441127, 'entre O': 0.0008901837015456826, 'les O': 0.011572388120093874, 'convives O': 0.00012138868657441127, 'ce O': 0.006433600388443797, 'qui O': 0.006474063283968601, 'est O': 0.011936554179817108, 'dommage O': 0.0006878692239216638, 'car O': 0.0015375900299425427, 'cuisine B-positive': 0.049443757725587144, 'bonne O': 0.001982681880715384, 'dans O': 0.006312211701869385, 'son O': 0.00129481265679372, 'ensemble O': 0.00012138868657441127, 'desserts B-negative': 0.00425531914893617, 'nous O': 0.008011653313911144, 'ont O': 0.0010115723881200939, 'été O': 0.0021849963583394027, 'comme O': 0.0016185158209921502, 'desserts O': 0.0002832402686736263, 'maison O': 0.0009711094925952901, 'mais O': 0.007445172776563891, 'plutôt O': 0.0008497208060208788, 'sortir O': 0.00012138868657441127, 'chez O': 0.00032370316419843, 'ou O': 0.0015780529254673463, 'autres O': 0.0005260176418224489, 'restauration O': 0.00012138868657441127, '! O': 0.017034879015942382, 'dessert B-negative': 0.005673758865248227, 'inexistant O': 0.00024277737314882253, '. O': 0.04317390952496561, '#UNK# B-negative': 0.14326241134751774, 'médiocres O': 0.000161851582099215, 'A O': 0.0020231447762401877, 'recommander O': 0.0003641660597232338, 'absolument O': 0.00048555474629764507, 'La O': 0.0031156429554098893, '#UNK# B-positive': 0.12484548825710753, 'de I-positive': 0.12334801762114538, 'veau I-positive': 0.00881057268722467, 'aussi O': 0.001335275552318524, ': O': 0.004005826656955572, 'top O': 0.00040462895524803755, 'en O': 0.00873998543335761, 'revanche O': 0.00020231447762401877, 'qu O': 0.0004450918507728413, 'ils O': 0.0007687950149712714, 'Cela O': 0.0006069434328720563, 'à O': 0.015254511612851015, 'être O': 0.001658978716516954, 'désagréable O': 0.0004450918507728413, 'cet O': 0.0006069434328720563, 'avis O': 0.0004450918507728413, 'malgré O': 0.0002832402686736263, 'ma O': 0.0007687950149712714, 'Nourriture B-neutral': 0.008403361344537815, 'classique O': 0.000161851582099215, 'yeux O': 0.00020231447762401877, 'fermés O': 0.000161851582099215, 'Bref O': 0.0010115723881200939, '.. O': 0.0007283321194464676, 'Les O': 0.0029942542688354778, 'plats B-negative': 0.04680851063829787, 'à I-negative': 0.01694915254237288, 'la I-negative': 0.00847457627118644, 'carte I-negative': 0.00423728813559322, 'sont O': 0.005260176418224488, 'hors O': 0.000161851582099215, 'prix O': 0.0032774945375091042, '( O': 0.005341102209274096, 'une O': 0.008780448328882414, '4 O': 0.00040462895524803755, '... O': 0.007607024358663106, 'certes O': 0.000161851582099215, 'bonnes O': 0.0006069434328720563, 'cela O': 0.0010520352836448977, 'fait O': 0.00258962531358744, 'beaucoup O': 0.0009711094925952901, ') O': 0.005260176418224488, 'et O': 0.02565347576272558, 'ne O': 0.006231285910819779, 'pas O': 0.014242939224730921, "d'une O": 0.00040462895524803755, 'qualité O': 0.003317957433033908, 'Nous O': 0.003924900865905964, 'sommes O': 0.0015375900299425427, 'arrivées O': 0.000161851582099215, 'vers O': 0.00020231447762401877, '- O': 0.0008092579104960751, 'Le O': 0.004936473254026058, 'un O': 0.015214048717326211, 'sans O': 0.004086752448005179, 'avons O': 0.0033584203285587115, 'bien O': 0.004774621671926843, 'On O': 0.0014162013433681314, 'peu O': 0.003924900865905964, 'genre O': 0.0002832402686736263, 'petite O': 0.00048555474629764507, 'brasserie B-neutral': 0.008403361344537815, ', O': 0.043902241644412074, 'déco B-positive': 0.009888751545117428, 'revoir O': 0.00020231447762401877, 'familiale O': 0.00012138868657441127, 'Un O': 0.0027110140001618517, 'menu B-negative': 0.00425531914893617, 'enfant I-negative': 0.00423728813 ...

# %% [markdown]
# #### (c) Implement a simple sentiment analysis system that produces the tag

# %%
def sentiment_analysis(word):
    all_tags = ["O", "B-positive", "I-positive", "B-negative", "I-negative", "B-neutral", "I-neutral"]
    scoreDict = {}
    # if word never appeared before, let it be #UNK#
    if word in modifiedWordDict:
        word = word
    else:
        word = "#UNK#"
    for tag in all_tags:
        possible_word_tag = word + " " + tag
        if giantEmissionDict.get(possible_word_tag) == None:
            scoreDict[tag] = 0
        else:
            scoreDict[tag] = giantEmissionDict[possible_word_tag]
            
    maximumScore = max(scoreDict.values())
    return max(scoreDict, key=scoreDict.get)

   
sentiment_analysis("ambience")
# Out:
# 'I-negative'

# %% [markdown]
# #### Loads dev.in file and store as dev_in_list

# %%
def load_files():
    with open("dev.in", encoding="utf-8") as file:
        dev_in_list = file.readlines()
        dev_in_list = [x.strip() for x in dev_in_list]
        return dev_in_list
        
dev_in_list = load_files()

# %%
import datetime
def predict_sentiment():
    wordDict = {}
    f = open("dev.p2.out","w+")
    giantStringToBeWritten = ""
    start = datetime.datetime.now()
    for i in range(len(dev_in_list)):
        each_word = dev_in_list[i]
        if each_word in wordDict:
            tag = wordDict[each_word]
            giantStringToBeWritten += each_word +  " " + tag + "\n"

        else:
            if each_word != "":
                tag = sentiment_analysis(each_word)
                wordDict[each_word] = tag 
                giantStringToBeWritten += each_word +  " " + tag + "\n"

            else:
                giantStringToBeWritten += " \n"


    f.write(giantStringToBeWritten)
    end = datetime.datetime.now()
    elapsed = end - start
    print(elapsed)

predict_sentiment()
# Out:
# 0:00:00.010712

# %% [markdown]
# ### Part 3
# #### Function to estimate Transition Parameters using MLE

# %% [markdown]
# #### Creating a giant_each_tweet_tag that contains only the states of each sentence

# %%
def separate_tweets():
    countStart = 1
    # counting starts
    giant_each_tweet = []
    each_tweet = []
    totalStateNumber = {}
    for i in range(len(modified_train_list)):
        annotated_word = modified_train_list[i]
        each_word = annotated_word.split(" ")
        if each_word == ['']:
            countStart += 1
            giant_each_tweet.append(each_tweet)
            each_tweet = []

        else:
            each_tweet.append(each_word[1])
    for i in range(len(giant_each_tweet)):
        giant_each_tweet[i].insert(0, 'START')
        giant_each_tweet[i].append('STOP')
    
    for each_tweet in giant_each_tweet:
        for tag in each_tweet:
            if totalStateNumber.get(tag) == None:
                totalStateNumber[tag] = 1
            else:
                totalStateNumber[tag] += 1

    return giant_each_tweet, countStart, totalStateNumber
giantTaggedEachTweet, countStart, totalStateNumber = separate_tweets()
print(totalStateNumber)
# Out:
# {'START': 1631, 'O': 24703, 'B-negative': 705, 'B-positive': 808, 'STOP': 1631, 'I-positive': 226, 'B-neutral': 119, 'I-negative': 236, 'I-neutral': 44}

# %%
def store_estimate_transition():
    giantTransitionDict = {}
    finalGiantTransitionDict = {}
    for taggedEachTweet in giantTaggedEachTweet:
        for i in range(len(taggedEachTweet) - 1):
            if giantTransitionDict.get(taggedEachTweet[i]+" "+taggedEachTweet[i+1]) == None:
                giantTransitionDict[taggedEachTweet[i]+" "+taggedEachTweet[i+1]] = 1
            else:
                giantTransitionDict[taggedEachTweet[i]+" "+taggedEachTweet[i+1]] += 1
    for eachTransition in giantTransitionDict:
        eachTransitionList = eachTransition.split(" ")
        startState = eachTransitionList[0]
        countTop = giantTransitionDict[eachTransition]
        countBottom = totalStateNumber[startState]
        transitionParam = countTop/countBottom
        finalGiantTransitionDict[eachTransition] = transitionParam
        
    return finalGiantTransitionDict
    
giantTransitionDict = store_estimate_transition()
print(giantTransitionDict)
# Out:
# {'START O': 0.9019006744328633, 'O O': 0.8748330162328463, 'O B-negative': 0.025422013520625026, 'B-negative O': 0.825531914893617, 'O B-positive': 0.029996356717807555, 'B-positive O': 0.8564356435643564, 'O STOP': 0.06557907946403271, 'START B-negative': 0.04721030042918455, 'B-positive I-positive': 0.13985148514851486, 'I-positive I-positive': 0.5, 'I-positive O': 0.49557522123893805, 'START B-neutral': 0.009809932556713672, 'B-neutral O': 0.8151260504201681, 'B-negative I-negative': 0.1673758865248227, 'I-negative I-negative': 0.5, 'I-negative O': 0.4957627118644068, 'O B-neutral': 0.004169534064688499, 'START B-positive': 0.041079092581238506, 'B-positive STOP': 0.0037128712871287127, 'B-neutral I-neutral': 0.17647058823529413, 'I-neutral I-neutral': 0.5227272727272727, 'I-neutral O': 0.4772727272727273, 'B-negative STOP': 0.0070921985815602835, 'I-negative STOP': 0.00423728813559322, 'I-positive STOP': 0.004424778761061947, 'B-neutral STOP': 0.008403361344537815}

# %%
def split_into_sentences(dev_in_list):
    sentences = []
    each_sentence = []
    for word in dev_in_list:
        if word == "":
            sentences.append(each_sentence)
            each_sentence = []
        else:
            each_sentence.append(word)
        
    return sentences
sentences = split_into_sentences(dev_in_list)

# %% [markdown]
# ## Viterbi

# %%
def find_path_backward(piList, sentence):
    path = []
    all_tags=["O","B-negative","B-positive","B-neutral","I-negative","I-positive","I-neutral"]
    if len(piList) == len(sentence):
#         print('sentence length and pilist length are same, move on')
        for i in range(len(piList)):
            # select the max of the last layer, use the max to find the previous value
            if i == 0: #its the start, i = 0 comes here
                lastLayer = piList[len(piList) - (i+1)]
                maxPiTag = max(lastLayer, key=lastLayer.get) 
                path.append('end')
            elif i == 1:
                path.append(maxPiTag)
            else: #i>0 comes here
                currentLayer = piList[len(piList) - (i+1)] #2nd last layer onwards
                targetedTag = path[i-1]
                scoreDict = {}
                for tag in currentLayer: 
                    if giantTransitionDict.get(tag + " " + targetedTag) != None:
                        scoreOfTag = giantTransitionDict[tag + " " + targetedTag] * currentLayer[tag]
                        scoreDict[tag] = scoreOfTag
                    
                bestScoreTag = max(scoreDict, key=scoreDict.get)
                path.append(bestScoreTag)
    singleStringToBeWritten = ""
    for j in range(len(sentence)):
        if sentence[j] == "":
            singleStringToBeWritten += "\n"
        else:
            singleStringToBeWritten += sentence[j] + " " + path[len(path)-(j+1)] + "\n"
    return singleStringToBeWritten

# expected: O, B-pos, I-pos, I-pos, I-pos, O, O, O
piList4 = [{'O': 0.10952242946302841, 'B-negative': 0.0019577571933592874, 'B-positive': 0.010624504726325918, 'B-neutral': 0.0009040105193951349}, {'O': 3.108819999877843e-05}, {'B-negative': 1.212411803650987e-09, 'B-positive': 3.5875587995634343e-09}, {'B-positive': 4.751733509355542e-11}]
sentence2 = ['AVOID', 'THE', 'PLACE', '']
find_path_backward(piList4, sentence2)
# Out:
# 'AVOID O\nTHE O\nPLACE B-positive\n\n'

# %%
def viterbi(sentence):
    all_tags=["O","B-negative","B-positive","B-neutral","I-negative","I-positive","I-neutral"]
    sentence.append("") #so we can detect the end
    beginning = True
    piList = []
#     for word in sentence:
    for i in range(len(sentence)):
        word = sentence[i]
        if word in modifiedWordDict:
            word = word
        else:
            word = "#UNK#"
        
        piLayer = {}
        if beginning: #base case
            for tag in all_tags:
                if giantTransitionDict.get("START" + " " + tag) != None and giantEmissionDict.get(word + " " + tag) != None:
                    pi = giantTransitionDict["START" + " " + tag]*giantEmissionDict[word + " " + tag]
                    piLayer[tag] = pi
            piList.append(piLayer)
            beginning = False
        else: #recursive
            previousLayer = piList[len(piList) - 1] #last entry of piList
            if word == "": #end of sentence
                tempLayer = {} 
                for previous_tag in previousLayer:
                    if giantTransitionDict.get(previous_tag + " " + "STOP") != None:
                        pi = previousLayer[previous_tag]*giantTransitionDict[previous_tag + " " + "STOP"] #new score
                        tempLayer[previous_tag] = pi
                if len(tempLayer) != 0:
                    maxPiTag = max(tempLayer, key=tempLayer.get)
                    maximumPiScore = max(tempLayer.values())
                    lastLayer = {}
                    lastLayer[maxPiTag] = maximumPiScore
                    piList.append(lastLayer)
                    singleStringToBeWritten = find_path_backward(piList, sentence)
                    return singleStringToBeWritten
                else:
                    return "ERROR"

            else: #if not end of sentence
                for tag in all_tags:
                    tempLayer = {}
                    for previous_tag in previousLayer:
                        if giantTransitionDict.get(previous_tag + " " + tag) != None and giantEmissionDict.get(word + " " + tag) != None:
                            pi = previousLayer[previous_tag]*giantTransitionDict[previous_tag + " " + tag]*giantEmissionDict[word + " " + tag]
                            tempLayer[previous_tag] = pi
                    # what if the length is 0? it will never transit to the tag
                    if len(tempLayer) != 0:
                        # pick the max here
                        maxPiTag = max(tempLayer, key=tempLayer.get) 
                        maxPiScore = max(tempLayer.values())
                        piLayer[tag] = maxPiScore
                piList.append(piLayer)


giantStringToBeWritten = ""
for sentence in sentences:
# singleStringToBeWritten = viterbi(['AVOID', 'THE', 'PLACE', ''])
    singleStringToBeWritten = viterbi(sentence)
    giantStringToBeWritten += singleStringToBeWritten
print(giantStringToBeWritten)
f = open("dev.p3.out","w+")
f.write(giantStringToBeWritten)
# Out:
# La O
# décoration B-positive
# est O
# horrible O
# . O
#
# Assiettes O
# de O
# tapas B-positive
# ridicules O
# . O
#
# Nous O
# avons O
# été O
# attiré O
# comme O
# les O
# autres O
# personnes O
# par O
# la O
# terrasse B-positive
# et O
# les O
# prix O
# bas O
# . O
#
# Le O
# plat B-neutral
# du I-neutral
# jour I-neutral
# comme O
# son O
# nom O
# l'indique O
# est O
# plutôt O
# un O
# gage O
# de O
# fraicheur O
# et O
# qualité O
# ; O
# ce O
# jour O
# là O
# si O
# le O
# sanglier O
# était O
# convenable O
# , O
# l O
# ' O
# accompagnement O
# très O
# limite O
# à O
# savoir O
# des O
# pâtes B-negative
# desséchées O
# et O
# froides O
# . O
#
# Très O
# bon O
# bistrot O
# . O
#
# Des O
# pizzas B-positive
# locales O
# que O
# vous O
# ne O
# mangerez O
# pas O
# ailleurs O
# , O
# accommodant O
# les O
# spécialités O
# du O
# coin O
# . O
#
# Ensuite O
# les O
# plats O
# ... O
# pas O
# de O
# doutes O
# la O
# spécialité O
# très O
# maîtrisé O
# est O
# le O
# burger O
# maison O
# ! O
#
# Reste O
# le O
# service B-negative
# , O
# sympathique O
# mais O
# un O
# peu O
# trop O
# décontracté O
# qui O
# ne O
# suffit O
# pas O
# à O
# relever O
# l'absence O
# de O
# qualité O
# de O
# ce O
# restaurant O
# . O
#
# En O
# bref O
# c O
# ' O
# est O
# certainement O
# un O
# des O
# meilleurs O
# bistrot O
# parisien O
# . O
#
# Du O
# jamais O
# vu O
# et O
# surtout O
# sans O
# intérêt O
# pour O
# mon O
# dessert O
# favori O
# qui O
# se O
# suffit O
# sans O
# artifice O
# ... O
#
# Portions O
# équilibrées O
# , O
# sauf O
# peut-être O
# pour O
# l O
# ' O
# entrée O
# ( O
# moules B-negative
# gratinées O
# ) O
# qui O
# était O
# trop O
# petite O
# tant O
# les O
# moules B-negative
# étaient O
# bonnes O
# . O
#
# Mais O
# plutôt O
# d'une O
# chose O
# pâteuse O
# trop O
# sucré O
# . O
#
# Le O
# restaurant O
# se O
# trouvant O
# au-dessus O
# du O
# marché O
# , O
# l O
# ' O
# ambiance B-positive
# est O
# garantie O
# . O
#
# Le O
# cadre B-positive
# est O
# vraiment O
# sympathique O
# et O
# la O
# déco B-positive
# très O
# agréable O
# ce O
# qui O
# contraste O
# avec O
# le O
# peu O
# d'amabilité O
# d'une O
# des O
# serveuses B-negative
# assez O
# désagréable O
# et O
# passée O
# maître O
# dans O
# l'art O
# de O
# faire O
# des O
# réflexions O
# à O
# la O
# clientèle O
# . O
#
# accueil B-positive
# sympathique O
# , O
# cuisine B-positive
# de O
# très O
# bonne O
# qualité O
# mais O
# parfois O
# la O
# main O
# est O
# un O
# peu O
# lourde O
# sur O
# le O
# sel O
# , O
# petit O
# problème O
# rectifié O
# depuis O
# . O
#
# La O
# prochaine O
# fois O
# , O
# eh O
# bien O
# il O
# n'y O
# en O
# aura O
# pas O
# ici O
# en O
# tout O
# cas O
# ! O
#
# Je O
# n'avais O
# qu'une O
# hâte O
# : O
# partir O
# ! O
#
# Avec O
# mon O
# conjoint O
# , O
# grands O
# amateurs O
# de O
# restaurants O
# asiatiques O
# , O
# nous O
# avons O
# été O
# très O
# déçus O
# . O
#
# Si O
# l'on O
# veut O
# deux O
# accompagnements O
# , O
# cela O
# est O
# même O
# compté O
# en O
# supplément O
# ! O
# ! O
#
# L O
# ' O
# assiette B-negative
# est O
# parfaite O
# de O
# l'entrée O
# jusqu'au O
# dessert O
# , O
# ce O
# qui O
# n'est O
# pas O
# si O
# fréquent O
# . O
#
# unique O
# à O
# Besançon O
# . O
#
# Nous O
# lui O
# avons O
# demandé O
# a O
# être O
# débarrassé O
# , O
# elle O
# ne O
# l'a O
# pas O
# fait O
# mais O
# est O
# passé O
# 3 O
# fois O
# devant O
# nous O
# les O
# mains O
# vides O
# ... O
# c'est O
# très O
# moyen O
# . O
#
# Arnaque O
# du O
# siècle O
# , O
# les O
# assiettes O
# sont O
# peu O
# fournies O
# , O
# les O
# plats O
# médiocres O
# et O
# le O
# rapport O
# qualité O
# / O
# prix O
# est O
# totalement O
# ahurissant O
# . O
#
# Des O
# associations O
# de O
# saveur O
# et O
# des O
# cuissons O
# impeccables O
# . O
#
# Une O
# serveuse B-negative
# nous O
# rattrapera O
# à O
# la O
# sortie O
# pour O
# s'excuser O
# et O
# nous O
# dire O
# que O
# nos O
# plats O
# sont O
# entrain O
# d'arriver O
# : O
# " O
# trop O
# tard O
# je O
# reprends O
# le O
# travail O
# dans O
# 15min O
# ! O
# " O
#
# Une O
# serveuse B-negative
# qui O
# s O
# ’ O
# ébouriffe O
# les O
# cheveux O
# derrière O
# le O
# bar O
# ... O
# Et O
# la O
# petite O
# touche O
# qui O
# va O
# bien O
# nous O
# sommes O
# ressortis O
# imprégnés O
# d'une O
# odeur O
# de O
# friture O
# ... O
#
# mérite O
# le O
# détour O
# ... O
# attention O
# : O
# réservez O
# ! O
#
# Que O
# ce O
# sois O
# les O
# entrées O
# ... O
# un O
# prix O
# très O
# abordable O
# ( O
# entre O
# 5 O
# et O
# 7 O
# euros O
# ) O
# pour O
# un O
# rapport O
# qualité O
# / O
# prix O
# exceptionnel O
# . O
#
# Le O
# pire O
# sont O
# les O
# toilettes O
# . O
#
# Et O
# gout O
# , O
# pas O
# du O
# tout O
# a O
# la O
# hauteur O
# du O
# prix O
# ! O
#
# Le O
# personnel B-positive
# est O
# très O
# prévenant O
# . O
#
# On O
# ne O
# peut O
# dire O
# que O
# du O
# bien O
# de O
# ce O
# restaurant O
# . O
#
# De O
# beaux O
# verres O
# auraient O
# été O
# appréciés O
# pour O
# boire O
# un O
# bon O
# vin O
# . O
#
# Jamais O
# nous O
# ne O
# retournerons O
# dans O
# ce O
# restaurant O
# . O
#
# Le O
# rapport O
# qualité-prix O
# reste O
# tendu O
# , O
# un O
# peu O
# cher O
# pour O
# les O
# repas O
# , O
# même O
# si O
# l O
# ' O
# espace O
# est O
# intéressant O
# , O
# entre O
# les O
# arbres O
# . O
#
# Situé O
# dans O
# une O
# petite O
# rue O
# du O
# vieux O
# centre O
# de O
# Gap O
# , O
# ce O
# restaurant O
# est O
# bien O
# décoré O
# . O
#
# Nous O
# avons O
# beaucoup O
# fréquenté O
# ce O
# petit O
# restaurant O
# , O
# mais O
# là O
# il O
# a O
# beaucoup O
# baissé O
# ... O
#
# Je O
# retournerais O
# avec O
# un O
# grand O
# plaisir O
# dans O
# ce O
# restaurant O
# . O
#
# Je O
# vous O
# le O
# déconseille O
# ... O
#
# Nous O
# avons O
# fait O
# la O
# remarque O
# à O
# la O
# serveuse B-negative
# qui O
# a O
# transmis O
# au O
# cuisinier O
# . O
#
# Vraiment O
# une O
# adresse B-positive
# à O
# retenir O
# pour O
# les O
# amateurs O
# de O
# viande B-negative
# , O
# une O
# entrecôte B-negative
# qui O
# fond O
# dans O
# la O
# bouche O
# , O
# une O
# sauce B-negative
# simple O
# mais O
# goûteuses O
# et O
# un O
# verre B-negative
# de I-negative
# vin I-negative
# de I-negative
# bonne O
# qualité O
# . O
#
# Après O
# minuit O
# les O
# habitués O
# fument O
# leurs O
# cigarettes O
# en O
# cachette O
# au O
# bar O
# . O
#
# Même O
# si O
# ' O
# l O
# ' O
# accueil B-positive
# est O
# sympa O
# et O
# courtois O
# , O
# les O
# prestations O
# souffrent O
# du O
# monopole O
# . O
#
# Pour O
# la O
# plupart O
# d'entre O
# nous O
# , O
# nous O
# avons O
# trouvé O
# notre O
# QG O
# du O
# quai O
# de O
# seine O
# ! O
#
# Ces O
# pauvres O
# poulpes O
# auraient O
# pu O
# mourir O
# d'un O
# excès O
# de O
# cholestérol O
# s'ils O
# n'avaient O
# pas O
# fini O
# sur O
# la O
# plancha O
# . O
#
# La O
# musique B-negative
# était O
# vraiment O
# très O
# forte O
# . O
#
# seul O
# le O
# vin O
# était O
# correct O
# en O
# rapport O
# Q O
# / O
# P O
# , O
# les O
# entrées O
# et O
# desserts O
# sont O
# inégaux O
# quant O
# à O
# eux O
# . O
#
# Je O
# ne O
# recommanderai O
# pas O
# ce O
# restaurant O
# et O
# n'y O
# retournerai O
# pas O
# ! O
#
# En O
# bref O
# , O
# la O
# qualité O
# du O
# service B-negative
# est O
# un O
# comble O
# pour O
# un O
# établissement B-positive
# mettant O
# en O
# avant O
# ses O
# influences O
# new-yorkaise O
# ! O
#
# Un O
# pain O
# qui O
# sut O
# de O
# l'eau O
# = O
# micro O
# onde O
# . O
#
# L O
# ' O
# apéro O
# est O
# étonnant O
# : O
# on O
# vous O
# sert O
# une O
# bouteille O
# de O
# 1 O
# litre O
# de O
# rhum O
# et O
# une O
# bouteille O
# de O
# sucre O
# canne O
# liquide O
# . O
#
# Un O
# cadre B-positive
# simple O
# mais O
# pourtant O
# très O
# authentique O
# et O
# étudié O
# ... O
# un O
# style O
# américain O
# années O
# 70 O
# tout O
# en O
# simplicité O
# et O
# goût O
# . O
#
# Une O
# bière B-negative
# pression O
# à O
# 3,7 O
# euros O
# sans O
# bulle O
# avec O
# un O
# goût O
# d'eau O
# , O
# bref O
# une O
# bière B-negative
# coupée O
# à O
# l'eau O
# . O
#
# Ce O
# sera O
# notre O
# incontournable O
# à O
# Cassis O
# ! O
#
# un O
# resto O
# qui O
# ravira O
# les O
# papilles O
# avec O
# des O
# produits B-positive
# très O
# bien O
# cuisinés O
# . O
#
# Une O
# adresse B-positive
# à O
# garder O
# pour O
# soi O
# vue O
# imprenable O
# sur O
# l O
# hippodrome O
# et O
# le O
# golf O
# pensez O
# à O
# réserver O
# en O
# bas O
# près O
# des O
# baies O
# vitrées O
# la O
# cuisine B-positive
# et O
# bonne O
# et O
# en O
# plus O
# le O
# service B-negative
# est O
# avec O
# le O
# sourire O
#
# Tout O
# d'abord O
# un O
# serveur B-negative
# nous O
# a O
# littéralement O
# sauté O
# dessus O
# lorsque O
# nous O
# lisions O
# la O
# carte B-positive
# , O
# malgré O
# cette O
# méthode O
# plutôt O
# brutale O
# le O
# contenu O
# de O
# la O
# carte B-positive
# avait O
# l'air O
# pas O
# mal O
# , O
# nous O
# avons O
# donc O
# décidés O
# d O
# ’ O
# accepter O
# , O
# ensuite O
# après O
# avoir O
# fait O
# notre O
# choix O
# , O
# l O
# ' O
# attente B-negative
# a O
# été O
# longue O
# , O
# heureusement O
# l'égarement O
# d'une O
# serveuse B-negative
# avec O
# ses O
# assiettes O
# nous O
# a O
# fait O
# passer O
# le O
# temps O
# , O
# elles O
# nous O
# a O
# fait O
# de O
# la O
# peine O
# . O
#
# Les O
# produits B-positive
# sont O
# de O
# saison O
# . O
#
# Service B-positive
# gentil O
# . O
#
# Ah O
# ! O
#
# Des O
# produits B-positive
# , O
# frais O
# , O
# joliment O
# présentés O
# et O
# très O
# bons O
# . O
#
# Le O
# soir O
# pas O
# de O
# menu O
# donc O
# ça O
# revient O
# super O
# cher O
# ( O
# rapport O
# qualité O
# \ O
# prix O
# on O
# ne O
# s'y O
# retrouve O
# pas O
# à O
# mon O
# sens O
# ) O
# . O
#
# Nous O
# n'y O
# mettrons O
# plus O
# les O
# pieds O
# ! O
#
# A O
# recommander O
# 1000 O
# fois O
# ! O
#
# 1 O
# ticket O
# Resto B-positive
# par O
# personne O
#
# Au O
# départ O
# nous O
# avions O
# déjà O
# l O
# impression O
# de O
# déranger O
# , O
# à O
# la O
# limite O
# pas O
# trop O
# grave O
# ville O
# touristique O
# et O
# beaucoup O
# de O
# monde O
# donc O
# je O
# pense O
# les O
# serveurs B-negative
# fatigués O
# . O
#
# Je O
# suis O
# allé O
# à O
# plusieurs O
# reprises O
# lors O
# de O
# mes O
# escapades O
# parisiennes O
# , O
# dîner O
# dans O
# cet O
# établissement B-positive
# bien O
# situé O
# . O
#
# Les O
# prix O
# pratiqués O
# sont O
# corrects O
# . O
#
# Que O
# le O
# chef O
# cherche O
# à O
# réiventer O
# les O
# classiques O
# lyonnais O
# , O
# pourquoi O
# pas O
# s'il O
# le O
# faisait O
# avec O
# talent O
# . O
#
# Digestion O
# compliqué O
# le O
# lendemain O
# tous O
# mes O
# amis O
# et O
# moi O
# même O
# ... O
#
# .. O
#
# Un O
# grand O
# remerciement O
# pour O
# cette O
# cuisine B-positive
# riche O
# moderne O
# et O
# pleine O
# de O
# saveur O
# , O
# merci O
# également O
# à O
# l O
# ' O
# accueil B-positive
# au O
# service B-negative
# , O
# la O
# gentillesse O
# et O
# le O
# professionnalisme O
# du O
# personnel B-positive
# merci O
# et O
# merci O
# encore O
#
# Si O
# le O
# plat O
# fut O
# correct O
# ( O
# saint O
# jacques O
# - O
# risotto O
# ) O
# ... O
# il O
# ne O
# fallait O
# pas O
# avoir O
# trop O
# faim O
# ... O
# seulement O
# trois O
# saint O
# jacques O
# le O
# tout O
# à O
# peine O
# chaud O
# . O
#
# On O
# a O
# même O
# vu O
# une O
# serveuse B-negative
# fumer O
# en O
# cuise O
# ! O
#
# Bien O
# situé O
# . O
#
# repas O
# et O
# un O
# vin O
# irréprochable O
# , O
# service B-negative
# impeccable O
# . O
#
# On O
# attire O
# les O
# clients O
# avec O
# un O
# panneau O
# de O
# photos O
# de O
# personnalités O
# de O
# passage O
# dans O
# le O
# restaurant O
# . O
#
# Certes O
# nous O
# n'avions O
# pas O
# un O
# gros O
# budget O
# , O
# 15 O
# € O
# par O
# personne O
# entrée O
# , O
# plat O
# , O
# gâteau O
# . O
#
# un O
# des O
# serveurs B-negative
# a O
# le O
# physique O
# d'un O
# enfant O
# de O
# 15ans O
# ;) O
# mais O
# très O
# dynamique O
# et O
# sympa O
# . O
#
# Une O
# équipe B-positive
# aimable O
# , O
# de O
# la O
# vraie O
# nourriture B-negative
# traditionnelle O
# française O
# , O
# fraîcheur O
# des O
# aliments O
# , O
# inventivité O
# ( O
# pieds O
# de O
# cochons O
# à O
# tester O
# :) O
# ) O
# dans O
# les O
# recettes O
# , O
# de O
# bon O
# petits O
# vins B-positive
# , O
# franchement O
# , O
# ça O
# fait O
# 4 O
# fois O
# que O
# j'y O
# vais O
# , O
# et O
# j'en O
# suis O
# toujours O
# ravie O
# ! O
#
# Rien O
# à O
# dire O
# , O
# simple O
# mais O
# très O
# bon O
# et O
# très O
# frais O
# . O
#
# Nous O
# avons O
# testé O
# de O
# nombreux O
# plats O
# différents O
# et O
# toujours O
# excellents O
# ! O
#
# Pas O
# un O
# merci O
# ... O
# quelle O
# tristesse O
# . O
#
# Très O
# belle O
# ambiance B-positive
# si O
# vous O
# aimez O
# la O
# lumière O
# tamisée O
# , O
# êtes O
# étudiants O
# ou O
# bobo O
# / O
# hipster O
# . O
#
# L'apéro O
# à O
# été O
# un O
# peu O
# accéléré O
# par O
# un O
# serveur B-negative
# visiblement O
# pressé O
# de O
# finir O
# son O
# service B-negative
# et O
# qui O
# est O
# venu O
# nous O
# proposer O
# de O
# goûter O
# le O
# vin O
# alors O
# que O
# nous O
# commentions O
# seulement O
# à O
# goûter O
# les O
# toast O
# de O
# tapenade O
# . O
#
# Les O
# desserts O
# maisons O
# apparemment O
# sont O
# corrects O
# . O
#
# tous O
# les O
# ingrédients O
# sont O
# réunis O
# pour O
# passer O
# une O
# très O
# bonne O
# soirée O
# ! O
#
# Moi O
# qui O
# n'écris O
# jamais O
# d'avis O
# , O
# je O
# me O
# dis O
# ce O
# soir O
# qu'il O
# s'agissait O
# peut-être O
# d'une O
# faute O
# de O
# goût O
# de O
# ma O
# part O
# ... O
#
# Tout O
# est O
# dit O
# . O
#
# Goût O
# affreux O
# - O
# surtout O
# ne O
# jamais O
# prendre O
# le O
# bœuf O
# d'un O
# derrier O
# goût O
# dégoûtant O
# dans O
# une O
# casserole O
# de O
# puré O
# de O
# pommes B-negative
# de I-negative
# terre I-negative
# comme O
# une O
# soupe B-positive
# amère O
# . O
#
# Nous O
# avons O
# été O
# attirés O
# par O
# les O
# prix O
# plutôt O
# corrects O
# . O
#
# Nous O
# avons O
# pris O
# une O
# pierre O
# chaude O
# pour O
# deux O
# . O
#
# Pour O
# rencontrer O
# des O
# gens O
# beaucoup O
# plus O
# sympas O
# . O
#
# Accueil B-negative
# très O
# sympathique O
# . O
#
# Des O
# serveurs B-negative
# antipathiques I-negative
# au I-negative
# possible O
# . O
#
# Un O
# tartare B-neutral
# de I-neutral
# saumon I-neutral
# avec O
# trop O
# d'oignons O
# . O
#
# Vous O
# regretterez O
# moins O
# l'addition O
# ! O
#
# Il O
# revient O
# après O
# vérification O
# en O
# me O
# disant O
# qu'il O
# s'agit O
# de O
# la O
# recette O
# des O
# moules B-negative
# marinières O
# . O
#
# Accueil B-negative
# très O
# très O
# sympa O
# ! O
# ! O
# ! O
# Nous O
# avons O
# très O
# bien O
# mangé O
# avec O
# des O
# plats O
# traditionnels O
# comme O
# à O
# la O
# maison O
# , O
# la O
# qualité O
# mais O
# aussi O
# la O
# quantité O
# sont O
# en O
# rdv O
# ! O
# ! O
# ! O
#
# Pas O
# de O
# responsable B-negative
# dans O
# le O
# restaurant O
# pour O
# répondre O
# à O
# nos O
# demandes O
# . O
#
# Pour O
# avoir O
# été O
# testé O
# par O
# des O
# membres O
# de O
# la O
# soirée O
# au O
# préalable O
# , O
# nous O
# sommes O
# tombés O
# d'accord O
# sur O
# le O
# fait O
# que O
# c'était O
# la O
# première O
# fois O
# pour O
# certains O
# et O
# la O
# dernière O
# fois O
# pour O
# tout O
# le O
# monde O
# que O
# nous O
# venions O
# dans O
# ce O
# restaurant O
# ! O
#
# Le O
# cadre B-positive
# et O
# le O
# personnel B-positive
# sont O
# agréables O
# . O
#
# Très O
# agréable O
# . O
#
# La O
# note O
# qui O
# nous O
# est O
# présentée O
# est O
# défalquée O
# d'une O
# cocotte O
# alors O
# que O
# plus O
# personne O
# ne O
# souhaite O
# manger O
# ces O
# moules B-negative
# douteuses O
# . O
#
# Service B-positive
# superbe O
# et O
# très O
# accueillant O
# , O
# malheureusement O
# ils O
# ne O
# savent O
# pas O
# décrire O
# les O
# plats O
# , O
# les O
# noms O
# originaux O
# des O
# plats O
# sont O
# incompréhensible O
# . O
#
# Mais O
# dans O
# l'assiette O
# aucune O
# cuisine B-positive
# , O
# du O
# réchauffé O
# industriel O
# comme O
# au O
# resto O
# d'entreprise O
# ! O
#
# j'ai O
# pris O
# bavette B-negative
# avec O
# des O
# frites O
# ! O
#
# A O
# deux O
# 19h O
# , O
# un O
# apéro O
# qui O
# se O
# transforme O
# en O
# dîner O
# . O
#
# L O
# ' O
# entrée O
# pas O
# bonne O
# , O
# plus O
# de O
# plat B-neutral
# du I-neutral
# jour I-neutral
# . O
#
# Arrivages O
# de O
# poissons B-positive
# journalier O
# , O
# donc O
# extra O
# frais O
# . O
#
# Quel O
# plaisir O
# dés O
# l O
# ' O
# accueil B-positive
# , O
# ce O
# grand O
# sourire O
# , O
# cette O
# bise O
# , O
# le O
# tout O
# très O
# naturel O
# , O
# on O
# n'est O
# plus O
# habitués O
# à O
# ce O
# coté O
# amical O
# , O
# surtout O
# à O
# Paris O
# ! O
#
# Encore O
# une O
# fois O
# ce O
# restau O
# semble O
# être O
# la O
# brasserie O
# à O
# touriste O
# typiquement O
# parisienne O
# qui O
# achète O
# ses O
# produits B-positive
# de O
# basse O
# qualité O
# chez O
# " O
# métro O
# " O
# et O
# vous O
# les O
# fait O
# payer O
# un O
# blinde O
# ! O
#
# Hésitant O
# au O
# départ O
# sur O
# le O
# choix O
# du O
# lieu B-positive
# , O
# un O
# bon O
# verre B-negative
# de I-negative
# vin I-negative
# , O
# des O
# bons O
# tapas B-positive
# de O
# qualité O
# engloutis O
# , O
# nous O
# avons O
# au O
# final O
# passé O
# une O
# excellente O
# soirée O
# avec O
# nos O
# amis O
# . O
#
# C'est O
# la O
# fin O
# de O
# service B-negative
# . O
#
# Salle O
# déserte O
# , O
# nous O
# étions O
# 6 O
# au O
# total O
# , O
# un O
# samedi O
# soir O
# ... O
#
# Pas O
# mal O
# , O
# mais O
# sans O
# plus O
# . O
#
# Ça O
# ne O
# vaut O
# certes O
# pas O
# le O
# prix O
# ... O
#
# Je O
# demande O
# au O
# serveur B-negative
# s'il O
# n'y O
# a O
# pas O
# un O
# souci O
# . O
#
# Le O
# cadre B-positive
# , O
# dîner O
# au O
# bord O
# de O
# la O
# piscine O
# . O
#
# Un O
# serveur B-negative
# sympathique O
# mais O
# c'est O
# le O
# seul O
# point O
# positif O
# . O
#
# une O
# pizza B-negative
# assez O
# bonne O
# mais O
# servie O
# sans O
# couverts O
# ? O
#
# situé O
# dans O
# la O
# petite O
# Venise O
# avec O
# terrasse B-positive
# au O
# bord O
# de O
# l'eau O
# , O
# l O
# ' O
# endroit B-positive
# semblait O
# idéal O
# pour O
# cette O
# journée O
# passée O
# à O
# Colmar O
# . O
#
# Excellent O
# dîner O
# , O
# serveuse B-negative
# très O
# aimable O
# , O
# et O
# ambiance B-positive
# tamisée O
# .. O
# Nous O
# avons O
# testé O
# plusieurs O
# entrées O
# et O
# plats O
# .. O
# Personne O
# n O
# a O
# été O
# déçu O
# . O
#
# Très O
# beau O
# menu O
# à O
# 35 O
# euros O
# le O
# midi O
# qui O
# change O
# tout O
# le O
# temps O
# . O
#
# Le O
# service B-negative
# est O
# très O
# correct O
# Nous O
# avons O
# passé O
# un O
# très O
# bon O
# moment O
# et O
# nous O
# vous O
# recommandons O
# l O
# ' O
# endroit B-positive
# . O
#
# Le O
# courant O
# est O
# très O
# bien O
# passé O
# avec O
# nous O
# et O
# pourtant O
# nous O
# étions O
# une O
# grande O
# tablée O
# de O
# 12 O
# personnes O
# très O
# actives O
# ! O
#
# 0 O
# sur O
# toute O
# la O
# ligne O
# . O
#
# Cela O
# reste O
# quand O
# même O
# un O
# bon O
# resto O
# , O
# a O
# tester O
# . O
#
# Personnel B-positive
# très O
# gentil O
# et O
# serviable O
# . O
#
# Première O
# table O
# où O
# l'on O
# nous O
# installe O
# , O
# l'ampoule O
# au O
# dessus O
# est O
# grillée O
# , O
# demi O
# obscurité O
# et O
# les O
# bougies O
# sur O
# le O
# côté O
# semblent O
# bien O
# couvertes O
# de O
# poussière O
# ... O
#
# Un O
# peu O
# vieillissant O
# . O
#
# Sans O
# parler O
# de O
# l'huile O
# ! O
#
# Entrée O
# , O
# plat O
# , O
# dessert O
# nous O
# avons O
# adoré O
# ! O
#
# dommage O
# , O
# c'est O
# vraiment O
# du O
# gâchis O
# ! O
# ! O
#
# Les O
# plats O
# sont O
# excellents O
# de O
# l'entrée O
# au O
# dessert O
# . O
#
# Pas O
# besoin O
# d'en O
# dire O
# plus O
# , O
# ce O
# bar O
# est O
# affreux O
#
# Une O
# belle O
# carte B-positive
# pleine O
# de O
# bonnes O
# surprises O
# . O
#
# Serveurs O
# désagréables O
# , O
# vous O
# etes O
# pas O
# du O
# coin O
# ? O
#
# Nous O
# laissons O
# une O
# seconde O
# chance O
# . O
#
# aucun O
# geste O
# commercial O
# au O
# paiement O
# , O
# rien O
# d'offert O
# ni O
# de O
# proposé O
# ... O
# ? O
# ? O
# ! O
#
# La O
# déco B-positive
# est O
# bas O
# de O
# gamme O
# et O
# clinquante O
# . O
#
# Lorsque O
# le O
# serveur B-negative
# nous O
# demande O
# si O
# ça O
# allait O
# , O
# je O
# lui O
# dis O
# que O
# la O
# viande B-negative
# était O
# bonne O
# mais O
# que O
# la O
# cuisson O
# n'était O
# pas O
# celle O
# que O
# j'avais O
# demandé O
# . O
#
# Si O
# vous O
# avez O
# la O
# santé O
# fragile O
# passez O
# votre O
# chemin O
# . O
#
# Entrée B-negative
# au I-negative
# chèvre I-negative
# chaud I-negative
# , O
# suivi O
# d'un O
# magret B-positive
# de I-positive
# canard I-positive
# miel I-positive
# / O
# citron O
# accompagné O
# de O
# pommes B-negative
# sautées O
# , O
# un O
# vrai O
# délice O
# ! O
#
# La O
# carte B-positive
# pourtant O
# est O
# bien O
# garnie O
# et O
# alléchante O
# . O
#
# Service B-positive
# très O
# perfectible O
# ( O
# lent O
# , O
# et O
# mal O
# organisé O
# ) O
# . O
#
# Il O
# prend O
# la O
# commande O
# sur O
# un O
# ton O
# excédé O
# en O
# se O
# retournant O
# pour O
# donner O
# des O
# ordres O
# aux O
# autres O
# serveurs B-negative
# . O
#
# Les O
# plats O
# sont O
# servis O
# en O
# quantité O
# suffisante O
# et O
# bien O
# chauds O
# . O
#
# Des O
# produits B-positive
# frais O
# avec O
# des O
# bonnes O
# positions O
# de O
# l O
# ' O
# équipe B-positive
# qui O
# est O
# au O
# petit O
# soin O
# . O
#
# Après O
# ça O
# mais O
# une O
# certaine O
# ambiance B-positive
# dans O
# la O
# salle O
# . O
#
# La O
# cuisine B-positive
# était O
# correcte O
# l O
# ' O
# ambiance B-positive
# sympa O
# . O
#
# Le O
# patron O
# est O
# vraiment O
# super O
# sympa O
# et O
# j'ai O
# même O
# eu O
# droit O
# à O
# une O
# pizza B-negative
# gratuite O
# sans O
# rien O
# demander O
# . O
#
# Burger O
# hyper O
# sec O
# , O
# mal O
# cuit O
# , O
# frites O
# sans O
# goût O
# à O
# part O
# celui O
# de O
# l'huile O
# , O
# bière B-negative
# chaude O
# ... O
# service B-negative
# assez O
# sympathique O
# et O
# qui O
# semblait O
# presque O
# plus O
# navré O
# que O
# nous O
# du O
# naufrage O
# total O
# de O
# cette O
# soirée O
# . O
#
# Côté O
# cuisine B-positive
# , O
# un O
# manque O
# complet O
# de O
# surprise O
# , O
# de O
# découverte O
# ou O
# d'audace O
# ... O
#
# Une O
# agression O
# inutile O
# qui O
# nous O
# a O
# gaché O
# la O
# soirée O
# . O
#
# Choix O
# du O
# buffet O
# très O
# restreint O
# . O
#
# Nous O
# avons O
# demandé O
# du O
# Coca-Cola O
# et O
# on O
# nous O
# a O
# servi O
# du O
# soda O
# discount O
# sans O
# nous O
# en O
# avoir O
# informé O
# , O
# qui O
# plus O
# est O
# il O
# était O
# chaud O
# . O
#
# On O
# aurait O
# du O
# se O
# méfier O
# du O
# restaurant O
# presque O
# vide O
# un O
# vendredi O
# soir O
# . O
#
# Ce O
# n'est O
# pas O
# à O
# tomber O
# par O
# terre O
#
# En O
# entrée O
# , O
# nous O
# avons O
# pris O
# le O
# haddock O
# façon O
# flammekueche O
# ( O
# délicieux O
# ) O
# et O
# une O
# sorte B-negative
# de I-negative
# canard I-negative
# confis I-negative
# en O
# gelée O
# avec O
# noix B-positive
# et O
# poires O
# ( O
# très O
# bon O
# ) O
# . O
#
# Dans O
# ce O
# quartier O
# tranquille O
# , O
# un O
# restaurant O
# où O
# l'on O
# peut O
# diner O
# dehors O
# sous O
# les O
# arcades O
# en O
# dégustant O
# une O
# très O
# bonne O
# cuisine B-positive
# de O
# saison O
# . O
#
# Bref O
# une O
# addition O
# très O
# salée O
# pour O
# un O
# repas O
# très O
# long O
# et O
# mangé O
# sans O
# plaisir O
# ! O
#
# Les O
# serveurs B-negative
# sont O
# très O
# souriants O
# et O
# patients O
# . O
#
# La O
# carte B-positive
# est O
# généreuse O
# . O
#
# Plats B-neutral
# bien O
# exécutés O
# , O
# les O
# sauces B-negative
# sont O
# également O
# bonnes O
#
# des O
# plats O
# sans O
# passion O
# , O
# vaisselle O
# cassée O
# , O
# plat B-neutral
# du I-neutral
# jour I-neutral
# ( O
# riz B-negative
# crustacés O
# en O
# gros O
# ) O
# très O
# sec O
# , O
# sans O
# sauce B-negative
# , O
# gambas O
# pas O
# fraîches O
# , O
# une O
# pauvre O
# décoration B-positive
# superflue O
# ... O
# bref O
# aucun O
# goût O
# . O
#
# La O
# sauce B-negative
# envahissait O
# le O
# poisson O
# . O
#
# 1ère O
# fois O
# que O
# le O
# service B-negative
# n'est O
# pas O
# à O
# la O
# hauteur O
# de O
# la O
# cuisine B-positive
# dans O
# les O
# restos O
# que O
# je O
# fréquente O
# à O
# Rennes O
# , O
# dommage O
# . O
#
# Un O
# lieu B-positive
# simple O
# ou O
# passer O
# une O
# agréable O
# soirée O
# ! O
#
# Attente O
# interminable O
# ! O
#
# Service B-positive
# aimable O
# . O
#
# Choix O
# de O
# plats O
# très O
# classique O
# , O
# et O
# qualité O
# des O
# plats O
# médiocre O
# . O
#
# Bons O
# cocktails B-positive
# et O
# barman O
# très O
# sympa O
# . O
#
# Pour O
# finir O
# le O
# fraisier O
# ( O
# plutot O
# une O
# mousse O
# décoré O
# de O
# quelques O
# fraises O
# ) O
# commandé O
# pour O
# l'anniversaire O
# nous O
# est O
# arrivé O
# sur O
# la O
# table O
# comme O
# un O
# cheveu O
# sur O
# la O
# soupe B-positive
# ! O
#
# La O
# cuisine B-positive
# est O
# excellente O
# dans O
# un O
# cadre B-positive
# original O
# dans O
# lequel O
# on O
# se O
# sent O
# bien O
# . O
#
# Un O
# restaurant O
# extrêmement O
# bien O
# situé O
# tout O
# en O
# haut O
# des O
# Champs O
# Elysée O
# ! O
#
# Comment O
# peut-on O
# dire O
# cuisine B-positive
# maison O
# avec O
# ces O
# asperges O
# en O
# boite O
# , O
# son O
# boeuf O
# bourguignon O
# rempli O
# de O
# bas O
# morceaux O
# ... O
# ces O
# escargots O
# decongeles O
# etc O
# ... O
# cuisine B-positive
# française O
# vraiment O
# ? O
#
# Le O
# saumon O
# n'était O
# pas O
# très O
# frais O
# et O
# la O
# dinde O
# pas O
# assez O
# cuite O
# . O
#
# passez O
# votre O
# chemin O
# ! O
#
# A O
# tester O
# absolument O
# et O
# venez O
# en O
# ayant O
# très O
# très O
# faim O
# ! O
#
# Les O
# entrées O
# sont O
# à O
# 7 O
# euros O
# et O
# copieuses O
# . O
#
# La O
# cuisine B-positive
# qui O
# mériterait O
# largement O
# une O
# étoile O
# au O
# Michelin O
# . O
#
# J'ai O
# tendance O
# à O
# avoir O
# des O
# apprioris O
# sur O
# les O
# repas O
# dans O
# les O
# brasseries O
# mais O
# la O
# nous O
# avons O
# été O
# satisfait O
# . O
#
# Accueil B-negative
# et O
# service B-negative
# sont O
# agréables O
# et O
# efficaces O
#
# Finalement O
# nous O
# avons O
# gagné O
# . O
#
# Un O
# bon O
# rapport O
# qualité O
# / O
# prix O
# . O
#
# Je O
# ne O
# conseillerais O
# pas O
# cet O
# établissement B-positive
# . O
#
# Ca O
# a O
# beaucoup O
# changé O
# , O
# nous O
# n'y O
# remettrons O
# plus O
# les O
# pieds O
# ... O
#
# La O
# salle O
# est O
# bien O
# mais O
# les O
# WC O
# ne O
# sont O
# pas O
# à O
# la O
# hauteur O
# . O
#
# Café O
# gourmand O
# : O
# café O
# et O
# une O
# part O
# de O
# tarte B-positive
# aux I-positive
# pommes O
# surgelée O
# ( O
# écrit O
# fait O
# maison O
# sur O
# la O
# carte B-positive
# ) O
#
# Bon O
# accueil B-positive
# mais O
# service B-negative
# un O
# peu O
# long O
# . O
#
# Assis O
# sur O
# des O
# chaises O
# de O
# jardin O
# peu O
# confortable O
# nous O
# attendons O
# l O
# apéro O
# qui O
# arrive O
# très O
# rapidement O
# le O
# seul O
# hic O
# c O
# est O
# la O
# différence O
# entre O
# nos O
# deux O
# verres O
# pour O
# le O
# même O
# alcool O
# 1/4 O
# de O
# quantité O
# différente O
# . O
#
# Certes O
# , O
# ce O
# n'est O
# pas O
# de O
# la O
# gastronomie O
# , O
# mais O
# on O
# ne O
# vient O
# pas O
# à O
# un O
# buffet O
# à O
# volonté O
# pour O
# cela O
# . O
#
# Des O
# plats O
# correctement O
# servis O
# , O
# un O
# pavé B-negative
# de O
# turbot O
# excellent O
# et O
# des O
# prix O
# corrects O
# pour O
# le O
# quartier O
# . O
#
# Service B-positive
# lamentable O
# , O
# viandes B-negative
# médiocres O
# et O
# note O
# très O
# salée O
# ! O
#
# Un O
# début O
# de O
# soirée O
# qui O
# commence O
# dans O
# un O
# bon O
# resto O
# , O
# comme O
# les O
# 1er O
# fois O
# une O
# Virgin O
# Colada O
# à O
# 6.50 O
# e O
# pour O
# se O
# mettre O
# en O
# appétit O
# et O
# un O
# accueil B-positive
# toujours O
# très O
# chaleureux O
# du O
# patron B-negative
# et I-negative
# de I-negative
# sa I-negative
# femme I-negative
# . O
#
# Superbe O
# accueil B-positive
# . O
#
# Oui O
# c'est O
# frais O
# , O
#
# Connaissant O
# bien O
# la O
# cuisine B-positive
# de O
# son O
# mari O
# je O
# ne O
# suis O
# pas O
# étonné O
# de O
# la O
# qualité O
# du O
# plat B-neutral
# du I-neutral
# jour I-neutral
# . O
#
# Mais O
# étant O
# donné O
# que O
# nous O
# étions O
# trop O
# nous O
# nombreux O
# ( O
# 13 O
# personnes O
# ) O
# , O
# nous O
# avons O
# été O
# installé O
# à O
# l'étage O
# ( O
# en O
# nous O
# faisant O
# bien O
# précisé O
# que O
# le O
# rez-de-chaussée O
# était O
# destiné O
# aux O
# habitués O
# et O
# amateur O
# de O
# football O
# et O
# que O
# si O
# nous O
# souhaitions O
# consommer O
# il O
# fallait O
# redescendre O
# pour O
# commander O
# ) O
# dans O
# un O
# espace O
# Iounge O
# à O
# peine O
# éclairé O
# pour O
# pouvoir O
# lire O
# le O
# menu O
# ( O
# nous O
# avons O
# dû O
# utiliser O
# les O
# lampes O
# de O
# nos O
# smartphone O
# ) O
# . O
#
# Attirés O
# par O
# la O
# devanture O
# se O
# déclinant O
# comme O
# plutôt O
# chic O
# , O
# certes O
# le O
# prix O
# du O
# menu O
# à O
# 15 O
# € O
# n'inspirait O
# pas O
# une O
# cuisine B-positive
# raffinée O
# ... O
# mais O
# là O
# c'est O
# pire O
# que O
# tout O
# ... O
#
# Un O
# excellent O
# repas O
# mélangeant O
# saveur O
# américaines O
# et O
# savoir O
# faire O
# français O
# de O
# l'entrée O
# jusqu'au O
# dessert O
# . O
#
# Quand O
# les O
# institutions O
# marseillaises O
# s'endorment O
# sur O
# leur O
# réputation O
# , O
# ne O
# sont O
# plus O
# fréquentées O
# que O
# par O
# les O
# touristes O
# . O
#
# ... O
#
# - O
# Des O
# serveuses B-negative
# / O
# serveurs B-negative
# sous O
# pression O
# ( O
# y O
# compris O
# en O
# tout O
# début O
# de O
# service B-negative
# lorsque O
# l'endroit O
# est O
# quasi-vide O
# ) O
# et O
# d'une O
# impolitesse O
# rare O
#
# On O
# reste O
# sur O
# sa O
# faim O
# , O
# on O
# en O
# redemande O
# , O
# mais O
# y'a O
# pas O
# de O
# rab O
# . O
#
# J'y O
# retournerai O
# certainement O
# pour O
# manger O
# un O
# plat O
# qui O
# sort O
# de O
# ce O
# qui O
# peut O
# se O
# faire O
# dans O
# le O
# vieux O
# lille O
# pour O
# attraper O
# le O
# touriste O
# , O
# même O
# si O
# j'aurais O
# aimé O
# quelques O
# euros O
# de O
# moins O
# sur O
# l'addition O
# . O
#
# Sommes O
# venus O
# avec O
# un O
# coupon O
# Groupon O
# . O
#
# A O
# faire O
# si O
# on O
# est O
# dans O
# le O
# coin O
# , O
# mais O
# pas O
# la O
# peine O
# de O
# s'y O
# précipiter O
# , O
# des O
# très O
# bon O
# bistros O
# c'est O
# pas O
# ce O
# qui O
# manque O
# à O
# Paris O
# . O
#
# Sans O
# parler O
# de O
# la O
# sangria O
# tout O
# simplement O
# délicieuse O
# ! O
#
# Je O
# connais O
# l'adresse O
# depuis O
# longtemps O
#
# Le O
# cadre B-positive
# est O
# somptueux O
# , O
# le O
# repas O
# est O
# très O
# correct O
# .. O
#
# Les O
# moins O
# : O
#
# Pour O
# deux O
# entrées O
# , O
# deux O
# plats O
# et O
# deux O
# desserts O
# à O
# la O
# carte B-positive
# avec O
# une O
# bouteille B-negative
# de I-negative
# vin I-negative
# nous O
# avons O
# trouvé O
# le O
# repas O
# assez O
# cher O
# pour O
# Castelnaudary O
# ( O
# 92 O
# € O
# ) O
# . O
#
# L O
# ’ O
# accueil B-positive
# laisse O
# à O
# penser O
# que O
# tout O
# va O
# bien O
# se O
# passer O
# mais O
# rien O
# ne O
# se O
# passe O
# . O
#
# Nous O
# avions O
# négocié O
# le O
# menu O
# avec O
# le O
# responsable B-negative
# et O
# nous O
# étions O
# confiant O
# étant O
# donné O
# que O
# nous O
# avions O
# fêté O
# les O
# 70 O
# ans O
# de O
# mon O
# beau O
# père O
# il O
# y O
# a O
# 3 O
# ans O
# et O
# que O
# nous O
# avions O
# été O
# complètement O
# satisfait O
# . O
#
# Une O
# cuisine B-positive
# savoureuse O
# faite O
# avec O
# amour O
# , O
# j'y O
# retourne O
# dés O
# que O
# je O
# peux O
# pour O
# moi O
# c'est O
# un O
# vrai O
# restaurant O
#
# La O
# nourriture B-negative
# est O
# moyenne O
#
# Le O
# service B-negative
# est O
# correct O
# poli O
# mais O
# sans O
# entrain O
# . O
#
# Un O
# rapport O
# qualité O
# prix O
# correct O
# . O
#
# REFUS O
# DU O
# PASSTIME O
# alors O
# qu'ils O
# sont O
# dedans O
# et O
# prévenu O
# à O
# la O
# réservation O
# et O
# en O
# arrivant O
# . O
#
# Une O
# vraie O
# déception O
# ! O
#
# Le O
# contenu O
# des O
# assiettes O
# est O
# tout O
# aussi O
# réussi O
# : O
# copieux O
# et O
# très O
# bon O
# de O
# l'entrée O
# aux O
# desserts O
# . O
#
# Mais O
# après O
# : O
#
# Les O
# plats O
# sont O
# classiques O
# mais O
# corrects O
# avec O
# un O
# prix O
# qui O
# l'est O
# aussi.Vient O
# ensuite O
# l O
# ' O
# ambiance B-positive
# musicale O
# qui O
# correspond O
# à O
# l'idée O
# que O
# l'on O
# se O
# fait O
# de O
# ses O
# endroits O
# . O
#
# Le O
# moelleux O
# speculos O
# / O
# chocolat O
# était O
# a O
# tom O
# et O
# pas O
# terre O
# . O
#
# Très O
# déçue O
# par O
# ce O
# restaurant O
#
# Manifestement O
# ce O
# restaurant O
# a O
# préféré O
# tout O
# miser O
# sur O
# le O
# cadre B-positive
# au I-positive
# détriment I-positive
# de I-positive
# la O
# cuisine B-positive
# ! O
#
# Carafe O
# d'eau O
# demandé O
# deux O
# fois O
# avant O
# de O
# l'avoir O
# . O
#
# Je O
# le O
# recommande O
# à O
# tout O
# le O
# monde O
# ! O
#
# On O
# pourrait O
# presque O
# se O
# croire O
# en O
# Bretagne O
# . O
#
# Et O
# l O
# ' O
# équipe B-positive
# est O
# adorable O
# ! O
# 27835

# %% [markdown]
# ## Viterbi try 3
