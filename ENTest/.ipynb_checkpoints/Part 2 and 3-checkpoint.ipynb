# %% [markdown]
# ## Part 2
# #### Load training file and create dictionary containing the occurrences of each annotation in the training set

# %%
def load_original_train():
    with open("train", encoding="utf-8") as file:
        train_list = file.readlines()
        train_list = [x.strip() for x in train_list]
        return train_list
    
train_list = load_original_train()

# %%
annotationDict = {"O": 0, "I-positive": 0, "B-positive": 0, "I-negative":0, "B-negative": 0, "I-neutral":0, "B-neutral":0}

for i in range(len(train_list)):
    annotated_word = train_list[i]
    each_word = annotated_word.split(" ")
    if (len(each_word) == 2):
        if each_word[1] == "O":
            annotationDict["O"] += 1
        elif each_word[1] == "I-positive":
            annotationDict["I-positive"] += 1
        elif each_word[1] == "B-positive":
            annotationDict["B-positive"] += 1
        elif each_word[1] == "I-negative":
            annotationDict["I-negative"] += 1
        elif each_word[1] == "B-negative":
            annotationDict["B-negative"] += 1
        elif each_word[1] == "I-neutral":
            annotationDict["I-neutral"] += 1
        elif each_word[1] == "B-neutral":
            annotationDict["B-neutral"] += 1

print(annotationDict)
# Out:
# {'O': 24242, 'I-positive': 607, 'B-positive': 1208, 'I-negative': 133, 'B-negative': 382, 'I-neutral': 23, 'B-neutral': 65}

# %% [markdown]
# #### (a) Write a function that estimates the emission parameters from the training set using MLE

# %%
def estimate_emission(word, tag):
    countTop = 0
    countBottom = annotationDict[tag]
    for i in range(len(train_list)):
        annotated_word = train_list[i]
        each_word = annotated_word.split(" ")
        if len(each_word) == 2:
            if (each_word[0] == word and each_word[1] == tag):
                countTop += 1

#         print(countTop)
#         print(countBottom)
    return countTop/countBottom

estimate_emission("service", "O")
# Out:
# 0.0004950086626515964

# %% [markdown]
# #### (b) Replace the words that appear less than k times in the training set with a special token #UNK# before training. This leads to a “modified training set”.

# %%
import datetime

def modify_trainingset(k):
        wordCountDict = {}
        for i in range(len(train_list)):
            annotated_word = train_list[i]
            each_word = annotated_word.split(" ")
            if each_word[0] in wordCountDict:
                wordCountDict[each_word[0]] += 1
            else:
                wordCountDict[each_word[0]] = 1
        
       
        wordToBeReplacedDict = {}
        wordToBeReplacedList = []
        for key in wordCountDict:
            if wordCountDict[key] < k:
                wordToBeReplacedList.append(key)

        start = datetime.datetime.now()
        for i in range(len(train_list)): 
            annotated_word = train_list[i]
            each_word = annotated_word.split(" ")
            if each_word[0] in wordToBeReplacedList:
                train_list[i] = "#UNK# " + each_word[1]


        modifiedTotalTrainSet = "\n".join(train_list)

        f = open("modified_train","w+")
        f.write(modifiedTotalTrainSet)
                            
        end = datetime.datetime.now()
        elapsed = end - start
        print(elapsed)

modify_trainingset(3)
# Out:
# 0:00:01.208553

# %% [markdown]
# #### Loads the modified training set into a list, and count the occurences of each word in the list and store it into a dictionary called modifiedWordDict

# %%
def load_modified_train_file():
    with open("modified_train", encoding="utf-8") as file:
        modified_train_list = file.readlines()
        modified_train_list = [x.strip() for x in modified_train_list]
        return modified_train_list
        
modified_train_list = load_modified_train_file()

# %%
def get_word_dict():
    modifiedWordDict = {}        
    for i in range(len(modified_train_list)):
        annotated_word = modified_train_list[i]
        each_word = annotated_word.split(" ")
        if each_word[0] in modifiedWordDict:
            modifiedWordDict[each_word[0]] += 1
        else:
            modifiedWordDict[each_word[0]] = 1

    return modifiedWordDict
    
modifiedWordDict = get_word_dict()

# %%
def count_word_tag_pair_dict():
    word_tag_pair_dict= {}
    for word_tag_pair in modified_train_list:
        if word_tag_pair_dict.get(word_tag_pair) == None:
            word_tag_pair_dict[word_tag_pair] = 1
        else:
            word_tag_pair_dict[word_tag_pair] += 1
    return word_tag_pair_dict

    
wordTagPairDict = count_word_tag_pair_dict()

# %% [markdown]
# #### Implement a fixed emission function

# %%
def estimate_emission_fix(word, tag):
        countTop = 0
        countBottom = annotationDict[tag]
        if word in modifiedWordDict:
            # do nothing
            word = word
            
        else:
            word = "#UNK#"

        for i in range(len(modified_train_list)):
            annotated_word = modified_train_list[i]
            each_word = annotated_word.split(" ")
            if (each_word[0] == word and each_word[1] == tag):
                countTop += 1
        return countTop/countBottom

estimate_emission_fix("I", "O")
# Out:
# 0.019511591452850426

# %% [markdown]
# #### Loop through the words once and store the emission value of each word tag pair into a giant dictionary called giantEmissionDict

# %%
def store_estimate_emission_fix():
    giantEmissionDict = {}
    for word_tag_pair in modified_train_list:
        if word_tag_pair != "":
            word_tag_pair_list = word_tag_pair.split(" ")
            countTop = wordTagPairDict[word_tag_pair]
            countBottom = modifiedWordDict[word_tag_pair_list[0]]
            emission = countTop/countBottom
            if giantEmissionDict.get(word_tag_pair) == None:
                giantEmissionDict[word_tag_pair] = countTop/countBottom
    return giantEmissionDict
    
giantEmissionDict = store_estimate_emission_fix()
print(giantEmissionDict)
# Out:
# {'We O': 1.0, 'were O': 1.0, 'then O': 1.0, '#UNK# O': 0.8190255220417634, 'for O': 0.9928825622775801, 'their O': 1.0, 'most O': 1.0, 'expensive O': 1.0, 'sake O': 0.4, '( O': 0.9302325581395349, '$ O': 0.9583333333333334, '20 O': 1.0, '+ O': 0.8, 'per O': 1.0, 'serving O': 1.0, ') O': 0.9325842696629213, 'when O': 1.0, 'we O': 1.0, 'in O': 0.9846153846153847, 'fact O': 1.0, 'a O': 1.0, 'of O': 0.9426751592356688, 'less O': 1.0, 'than O': 1.0, 'half O': 0.75, 'that O': 1.0, 'price O': 0.9333333333333333, '. O': 1.0, '#UNK# B-neutral': 0.0031902552204176333, 'is O': 1.0, 'nothing O': 1.0, 'special O': 0.5384615384615384, 'Great O': 1.0, '#UNK# B-positive': 0.0849767981438515, 'and O': 0.9732824427480916, 'worth O': 1.0, 'every O': 1.0, 'bit O': 1.0, 'delicious O': 1.0, 'bagels B-positive': 0.625, ', O': 0.9947257383966245, 'especially O': 1.0, 'right O': 1.0, 'out O': 1.0, 'the O': 0.9936823104693141, 'Go O': 0.8181818181818182, 'here O': 1.0, 'Highly O': 1.0, 'recommended O': 1.0, '! O': 1.0, 'But O': 1.0, 'who O': 1.0, 'says O': 1.0, 'anything O': 1.0, 'about O': 1.0, 'service B-negative': 0.26865671641791045, 'The O': 0.9869706840390879, 'atmosphere O': 0.034482758620689655, 'was O': 1.0, 'an O': 1.0, 'crowd O': 0.8333333333333334, 'but O': 1.0, 'there O': 1.0, 'few O': 1.0, 'mid O': 1.0, "' O": 0.9411764705882353, 's O': 0.625, '/ O': 0.8, '30 O': 1.0, 'year O': 1.0, 'also O': 1.0, 'Just O': 1.0, 'up O': 1.0, 'cheap O': 1.0, 'good O': 0.9937106918238994, 'food B-positive': 0.504, 'had O': 1.0, 'to O': 0.9958246346555324, 'wait O': 0.8157894736842105, 'everything O': 1.0, 'ask O': 1.0, 'several O': 1.0, 'different O': 1.0, 'people O': 0.75, 'same O': 1.0, 'thing O': 1.0, 'before O': 1.0, 'be O': 1.0, 'served O': 1.0, 'This O': 1.0, 'great O': 1.0, 'place O': 0.4049079754601227, 'get O': 1.0, 'meal B-positive': 0.6, 'so O': 1.0, 'now O': 1.0, 'what O': 1.0, 'are O': 1.0, 'appetizers O': 0.6666666666666666, '? O': 1.0, 'I O': 1.0, 'dining O': 0.7333333333333333, 'at O': 1.0, 'Casa B-negative': 0.5, 'La I-negative': 0.14285714285714285, 'Femme I-negative': 0.5, 'like O': 1.0, 'no O': 1.0, 'other O': 1.0, 'experience O': 1.0, 'It O': 1.0, "wasn't O": 1.0, 'freshest O': 1.0, 'seafood B-neutral': 0.1, 'ever O': 1.0, 'taste O': 1.0, 'presentation O': 1.0, 'OK O': 1.0, 'They O': 1.0, 'have O': 1.0, 'authentic O': 1.0, 'Indian B-positive': 0.3125, 'prices O': 1.0, 'special I-positive': 0.34615384615384615, 'my O': 1.0, 'husband O': 1.0, 'steak B-positive': 0.14285714285714285, 'service B-positive': 0.5895522388059702, 'food B-neutral': 0.04, 'decent O': 1.0, 'i O': 1.0, 'am O': 1.0, 'never O': 1.0, 'disappointed O': 1.0, 'with O': 0.9420289855072463, 'everyone O': 1.0, 'helpful O': 1.0, '#UNK# I-positive': 0.061194895591647334, 'even O': 1.0, 'table O': 0.9428571428571428, 'it O': 1.0, 'me O': 1.0, '– O': 1.0, 'breakfast B-positive': 0.42857142857142855, 'When O': 1.0, 'got O': 1.0, 'sat O': 1.0, 'stairs O': 1.0, 'where O': 1.0, 'atmosphere B-positive': 0.7586206896551724, 'cozy O': 1.0, '& O': 1.0, 'horrible O': 1.0, 'far O': 1.0, 'from O': 1.0, 'small O': 0.95, 'street O': 1.0, "it's O": 1.0, 'on O': 0.9798657718120806, 'Save O': 1.0, 'yourself O': 1.0, 'waste O': 1.0, 'time O': 1.0, 'NOT O': 1.0, 'visit O': 1.0, 'course O': 0.7142857142857143, 'Also O': 1.0, 'they O': 1.0, '15 O': 1.0, 'each O': 1.0, 'guy O': 0.75, 'seat O': 1.0, 'her O': 1.0, 'she O': 1.0, 'left O': 1.0, 'by O': 0.9672131147540983, 'four O': 0.8571428571428571, 'us O': 1.0, 'not O': 1.0, 'told O': 1.0, 'him O': 1.0, 'years O': 1.0, 'world O': 1.0, 'including O': 1.0, 'seen O': 1.0, 'such O': 1.0, 'bad O': 1.0, '#UNK# B-negative': 0.020301624129930394, 'restaurant O': 0.5700934579439252, 'really O': 1.0, 'liked O': 1.0, 'this O': 1.0, 'place B-positive': 0.3987730061349693, 'filet B-positive': 0.8333333333333334, 'mignon I-positive': 1.0, 'dish I-positive': 0.25, 'superb O': 1.0, 'casual O': 1.0, 'just O': 1.0, 'bite O': 1.0, 'eat O': 1.0, 'been O': 1.0, 'both O' ...

# %% [markdown]
# #### (c) Implement a simple sentiment analysis system that produces the tag

# %%
def sentiment_analysis(word):
    all_tags = ["O", "B-positive", "I-positive", "B-negative", "I-negative", "B-neutral", "I-neutral"]
    scoreDict = {}
    # if word never appeared before, let it be #UNK#
    if word in modifiedWordDict:
        word = word
    else:
        word = "#UNK#"
    for tag in all_tags:
        possible_word_tag = word + " " + tag
        if giantEmissionDict.get(possible_word_tag) == None:
            scoreDict[tag] = 0
        else:
            scoreDict[tag] = giantEmissionDict[possible_word_tag]
            
    maximumScore = max(scoreDict.values())
    return max(scoreDict, key=scoreDict.get)

   
sentiment_analysis("ambience")
# Out:
# 'B-positive'

# %% [markdown]
# #### Loads dev.in file and store as dev_in_list

# %%
def load_files():
    with open("dev.in", encoding="utf-8") as file:
        dev_in_list = file.readlines()
        dev_in_list = [x.strip() for x in dev_in_list]
        return dev_in_list
        
dev_in_list = load_files()

# %%
import datetime
def predict_sentiment():
    wordDict = {}
    f = open("dev.p2.out","w+")
    giantStringToBeWritten = ""
    start = datetime.datetime.now()
    for i in range(len(dev_in_list)):
        each_word = dev_in_list[i]
        if each_word in wordDict:
            tag = wordDict[each_word]
            giantStringToBeWritten += each_word +  " " + tag + "\n"

        else:
            if each_word != "":
                tag = sentiment_analysis(each_word)
                wordDict[each_word] = tag 
                giantStringToBeWritten += each_word +  " " + tag + "\n"

            else:
                giantStringToBeWritten += " \n"


    f.write(giantStringToBeWritten)
    end = datetime.datetime.now()
    elapsed = end - start
    print(elapsed)

predict_sentiment()
# Out:
# 0:00:00.015362

# %% [markdown]
# ### Part 3
# #### Function to estimate Transition Parameters using MLE

# %% [markdown]
# #### Creating a giant_each_tweet_tag that contains only the states of each sentence

# %%
def separate_tweets():
    countStart = 1
    # counting starts
    giant_each_tweet = []
    each_tweet = []
    totalStateNumber = {}
    for i in range(len(modified_train_list)):
        annotated_word = modified_train_list[i]
        each_word = annotated_word.split(" ")
        if each_word == ['']:
            countStart += 1
            giant_each_tweet.append(each_tweet)
            each_tweet = []

        else:
            each_tweet.append(each_word[1])
    for i in range(len(giant_each_tweet)):
        giant_each_tweet[i].insert(0, 'START')
        giant_each_tweet[i].append('STOP')
    
    for each_tweet in giant_each_tweet:
        for tag in each_tweet:
            if totalStateNumber.get(tag) == None:
                totalStateNumber[tag] = 1
            else:
                totalStateNumber[tag] += 1

    return giant_each_tweet, countStart, totalStateNumber
giantTaggedEachTweet, countStart, totalStateNumber = separate_tweets()
print(totalStateNumber)
# Out:
# {'START': 1872, 'O': 24232, 'STOP': 1872, 'B-neutral': 65, 'B-positive': 1208, 'B-negative': 381, 'I-negative': 133, 'I-positive': 607, 'I-neutral': 23}

# %%
def store_estimate_transition():
    giantTransitionDict = {}
    finalGiantTransitionDict = {}
    for taggedEachTweet in giantTaggedEachTweet:
        for i in range(len(taggedEachTweet) - 1):
            if giantTransitionDict.get(taggedEachTweet[i]+" "+taggedEachTweet[i+1]) == None:
                giantTransitionDict[taggedEachTweet[i]+" "+taggedEachTweet[i+1]] = 1
            else:
                giantTransitionDict[taggedEachTweet[i]+" "+taggedEachTweet[i+1]] += 1
    for eachTransition in giantTransitionDict:
        eachTransitionList = eachTransition.split(" ")
        startState = eachTransitionList[0]
        countTop = giantTransitionDict[eachTransition]
        countBottom = totalStateNumber[startState]
        transitionParam = countTop/countBottom
        finalGiantTransitionDict[eachTransition] = transitionParam
        
    return finalGiantTransitionDict
    
giantTransitionDict = store_estimate_transition()
print(giantTransitionDict)
# Out:
# {'START O': 0.9401709401709402, 'O O': 0.8601436117530538, 'O STOP': 0.07622152525586003, 'START B-neutral': 0.005341880341880342, 'B-neutral O': 0.7846153846153846, 'O B-positive': 0.04646748101683724, 'B-positive O': 0.6887417218543046, 'O B-negative': 0.014897655992076594, 'B-negative O': 0.7821522309711286, 'B-negative I-negative': 0.2099737532808399, 'I-negative I-negative': 0.39849624060150374, 'I-negative O': 0.6015037593984962, 'O B-neutral': 0.002269725982172334, 'B-positive I-positive': 0.2980132450331126, 'I-positive O': 0.5848434925864909, 'I-positive I-positive': 0.40691927512355847, 'START B-positive': 0.0438034188034188, 'B-neutral I-neutral': 0.2, 'I-neutral I-neutral': 0.43478260869565216, 'I-neutral O': 0.5652173913043478, 'B-negative STOP': 0.007874015748031496, 'START B-negative': 0.010683760683760684, 'I-positive STOP': 0.008237232289950576, 'B-positive STOP': 0.013245033112582781, 'B-neutral STOP': 0.015384615384615385}

# %%
def extract_path(piLayer, wordList):
#     print(piLayer)
#     print(wordList)
    maximum = max(piLayer, key=piLayer.get)
    best_path = piLayer[maximum][0]
    best_path_list = best_path.split(',')
    best_path_list.remove('START')
    best_path_list.remove('STOP')

    giantStringToBeWrittenToFile = ""
    for i in range(len(best_path_list)):
        if (wordList[i] == ''):
            giantStringToBeWrittenToFile += " \n"
        else:
            giantStringToBeWrittenToFile += wordList[i] + " " + best_path_list[i] + "\n"

    return giantStringToBeWrittenToFile

        
wordList = ['When', 'I', 'called', 'this', 'morning', ',', 'I', "didn't", 'think', 'I', 'would', 'be', 'able', 'to', 'get', 'in', 'at', '12', ',', 'but', 'I', 'was', 'able', 'to', 'get', 'in', ',', 'along', 'with', 'four', 'other', 'guests', '.', '']
lastPiLayer = {'O': ['START,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,O,STOP', 1.639577736548346e-87]}
extract_path(lastPiLayer,wordList)
# Out:
# "When O\nI O\ncalled O\nthis O\nmorning O\n, O\nI O\ndidn't O\nthink O\nI O\nwould O\nbe O\nable O\nto O\nget O\nin O\nat O\n12 O\n, O\nbut O\nI O\nwas O\nable O\nto O\nget O\nin O\n, O\nalong O\nwith O\nfour O\nother O\nguests O\n. O\n \n"

# %%
def split_into_sentences(dev_in_list):
    sentences = []
    each_sentence = []
    for word in dev_in_list:
        if word == "":
            sentences.append(each_sentence)
            each_sentence = []
        else:
            each_sentence.append(word)
        
    return sentences
sentences = split_into_sentences(dev_in_list)

# %%
def viterbi(sentence):
#     print(sentence)
    all_tags=["O","B-negative","B-positive","B-neutral","I-negative","I-positive","I-neutral"]
    sentence.append("") #so we can detect the end
    beginning = True
    piList = []
    for word in sentence:
        
        if word in modifiedWordDict:
            word = word
        else:
            word = "#UNK#"
        
        piLayer = {}
        ## handle last word
        
            
        if beginning:
#             print(word)
            for tag in all_tags:
                if giantTransitionDict.get("START" + " " + tag) != None and giantEmissionDict.get(word + " " + tag) != None:
                    pi = giantTransitionDict["START" + " " + tag]*giantEmissionDict[word + " " + tag]
                    piLayer[tag] = ["START," + tag, pi]
            piList.append(piLayer)
            beginning = False
        else:
            previousLayer = piList[len(piList) - 1]
            if word == "":
#                 print(word)
#                 print("LAST WORD")
                tempLayer = {} 
                for previous_tag in previousLayer:
                    if giantTransitionDict.get(previous_tag + " " + "STOP") != None:
                        pi = previousLayer[previous_tag][1]*giantTransitionDict[previous_tag + " " + "STOP"]
                        tempLayer[previous_tag] = pi

                if len(tempLayer) != 0:
                    maxPiTag = max(tempLayer, key=tempLayer.get)
                    maximumPiScore = max(tempLayer.values())
                    tempLayer[maxPiTag] = [previousLayer[maxPiTag][0]+","+maxPiTag + ",STOP",maximumPiScore]
                    piList.append(tempLayer)
                    singleStringToBeWritten = extract_path(piList[len(piList)-1], sentence)
                    return singleStringToBeWritten
                else:
                    return "ERROR"
#                     print(singleStringToBeWritten)
            else:
#                 print(word)
                piLayer = {}
                for tag in all_tags:
                    tempLayer = {}
                    for previous_tag in previousLayer:
                        if giantTransitionDict.get(previous_tag + " " + tag) != None and giantEmissionDict.get(word + " " + tag) != None:
                            pi = giantTransitionDict[previous_tag + " " + tag]*giantEmissionDict[word + " " + tag]
                            tempLayer[tag] = pi
    #                         piLayer[tag] = ["START," + tag, pi]
                    if len(tempLayer) != 0:
                        maxPiTag = max(tempLayer, key=tempLayer.get)
                        maxPiScore = max(tempLayer.values())
                        if previousLayer.get(maxPiTag) != None:
                            piLayer[maxPiTag] = [previousLayer[maxPiTag][0]+","+maxPiTag, maxPiScore]

                piList.append(piLayer)
        # elif handle last word
    
    #extracting the best path
#     singleStringToBeWritten = extract_path(piList[len(piList)-1], wordList)
#     print(singleStringToBeWritten)
    
    

# for i in range(len(sentences)):
#     if i == 1:
#         viterbi(sentences[i])
giantStringToBeWritten = ""
for sentence in sentences:
    singleStringToBeWritten = viterbi(sentence)
    giantStringToBeWritten += singleStringToBeWritten
print(giantStringToBeWritten)
# Out:
# When O
# I O
# called O
# this O
# morning O
# , O
# I O
# didn't O
# think O
# I O
# would O
# be O
# able O
# to O
# get O
# in O
# at O
# 12 O
# , O
# but O
# I O
# was O
# able O
# to O
# get O
# in O
# , O
# along O
# with O
# four O
# other O
# guests O
# . O
#
# The O
# tuna O
# and O
# wasabe O
# potatoes O
# are O
# excellent O
# . O
#
# My O
# favortie O
# pizza O
# joint O
# in O
# Seattle O
#
# Food O
# wise O
# , O
# its O
# ok O
# but O
# a O
# bit O
# pricey O
# for O
# what O
# you O
# get O
# considering O
# the O
# restaurant O
# isn't O
# a O
# fancy O
# place O
# . O
#
# – O
# tucked O
# away O
# over O
# by O
# the O
# Beverly O
# Center O
# . O
#
# My O
# mouth O
# felt O
# very O
# dry O
# afterwards O
# and O
# I O
# had O
# that O
# signature O
# ? O
# MSG O
# ? O
# taste O
# lingering O
# in O
# my O
# throat O
# after O
# I O
# left O
# the O
# restaurant O
# . O
#
# It's O
# a O
# tiny O
# place O
# so O
# if O
# you O
# get O
# there O
# before O
# 8p O
# m O
# on O
# a O
# weekend O
# ( O
# Thurs O
# ? O
# Sun O
# ) O
# you O
# will O
# find O
# it O
# easier O
# to O
# get O
# a O
# table O
# or O
# a O
# seat O
# at O
# the O
# sushi O
# bar O
# . O
#
# The O
# wine O
# list O
# is O
# wonderful O
# and O
# the O
# food O
# reminds O
# me O
# of O
# my O
# recent O
# trip O
# to O
# Italy O
# . O
#
# We O
# all O
# agreed O
# that O
# mare O
# is O
# one O
# of O
# the O
# best O
# seafood O
# restaurants O
# in O
# New O
# York O
# . O
#
# Believe O
# it O
# baby O
# ! O
#
# We O
# have O
# since O
# returned O
# and O
# also O
# had O
# a O
# great O
# experience O
# , O
# sampling O
# more O
# small O
# plates O
# and O
# a O
# variety O
# of O
# the O
# beer O
# ( O
# cold O
# and O
# good O
# ) O
# . O
#
# Compared O
# to O
# Ess-a O
# , O
# Tal O
# offers O
# a O
# less O
# doughy O
# bagel O
# ! O
#
# It O
# was O
# so O
# much O
# though O
# that O
# I O
# could O
# barely O
# finish O
# but O
# I O
# did O
# , O
# since O
# it O
# was O
# delicious O
# . O
#
# the O
# staff O
# was O
# very O
# nice O
# and O
# courteous O
# and O
# obviously O
# chinese O
# . O
#
# This O
# was O
# , O
# from O
# start O
# to O
# finish O
# , O
# a O
# mind-bogglingly O
# uncomfortable O
# experience O
# . O
#
# I O
# went O
# here O
# with O
# a O
# friend O
# on O
# a O
# whim O
# , O
# we O
# went O
# someplace O
# else O
# first O
# and O
# couldn't O
# get O
# a O
# table O
# . O
#
# We O
# concluded O
# with O
# tiramisu O
# chocolate O
# cake O
# , O
# both O
# were O
# delicious O
# . O
#
# Not O
# much O
# of O
# a O
# selection O
# of O
# bottled O
# beer O
# either O
# , O
# we O
# went O
# with O
# Brahma O
# . O
#
# ERRORI'll O
# be O
# back O
# for O
# sure O
# . O
#
# Good O
# Experience O
#
# The O
# lox O
# is O
# always O
# fresh O
# too O
# . O
#
# ERRORWe've O
# tried O
# before O
# but O
# it O
# always O
# packed O
# and O
# doesn't O
# take O
# reservations O
# . O
#
# Beautiful O
# experience O
# . O
#
# Good O
# drink O
# . O
#
# There O
# is O
# " O
# Expensive-but-worth-it O
# " O
# and O
# there O
# is O
# " O
# Expensive-and-WTF O
# " O
# ? O
#
# And O
# it O
# was O
# quick O
# which O
# is O
# very O
# important O
# . O
#
# ERRORERRORERRORThe O
# place O
# itself O
# is O
# beautiful O
# the O
# bar O
# scene O
# seems O
# to O
# be O
# happening O
# . O
#
# Also O
# , O
# the O
# sandwiches O
# ( O
# nearing O
# $ O
# 7 O
# ) O
# didn't O
# come O
# with O
# anything O
# like O
# chips O
# or O
# a O
# side O
# . O
#
# The O
# stuff O
# tilapia O
# was O
# horrid O
# ... O
# tasted O
# like O
# cardboard O
# . O
#
# You O
# can O
# easily O
# hear O
# him O
# though O
# so O
# it O
# was O
# a O
# pleasant O
# sound O
# and O
# not O
# overbearing O
# . O
#
# It's O
# definately O
# not O
# a O
# place O
# to O
# go O
# if O
# you O
# want O
# to O
# impress O
# someone O
# . O
#
# ERRORERRORERRORWe O
# refused O
# to O
# pay O
# for O
# it O
# because O
# at O
# this O
# point O
# it O
# had O
# nothing O
# to O
# do O
# with O
# the O
# food O
# anymore O
# . O
#
# The O
# naan O
# was O
# some O
# of O
# the O
# best O
# I've O
# had O
# and O
# I O
# really O
# enjoyed O
# the O
# bhartha O
# , O
# not O
# too O
# tomatoey O
# . O
#
# Fabulous O
# food O
# - O
# if O
# the O
# front O
# of O
# house O
# staff O
# don't O
# put O
# you O
# off O
# – O
#
# Single O
# Worst O
# Restaurant O
# in O
# Manhattan O
#
# Inside O
# is O
# a O
# little O
# cramped O
# , O
# but O
# to O
# be O
# expected O
# . O
#
# However O
# , O
# they O
# do O
# take O
# your O
# cellphone O
# numbers O
# so O
# that O
# you O
# can O
# go O
# hang O
# out O
# somewhere O
# else O
# till O
# they O
# call O
# you O
# up O
# on O
# your O
# cellphone O
# . O
#
# Go O
# to O
# japanese O
# sushi O
# place O
# or O
# Spanish O
# tapas O
# place O
# - O
# this O
# creation O
# in O
# Williamsburg O
# is O
# a O
# misstake O
# . O
#
# Not O
# one O
# to O
# jump O
# to O
# complaints O
# ( O
# hence O
# my O
# lack O
# of O
# previous O
# online O
# reviewing O
# ) O
# , O
# I O
# called O
# the O
# restaurant O
# to O
# give O
# them O
# a O
# heads O
# up O
# that O
# their O
# kitchen O
# might O
# want O
# to O
# check O
# the O
# cleanliness O
# of O
# their O
# prep O
# stations O
# . O
#
# I'm O
# glad O
# I O
# was O
# introduced O
# to O
# this O
# place O
# and O
# this O
# is O
# a O
# rare O
# gem O
# in O
# NY O
# . O
#
# It's O
# a O
# rather O
# cramped O
# and O
# busy O
# restaurant O
# and O
# it O
# closes O
# early O
# . O
#
# The O
# food O
# is O
# fantastic O
# , O
# authentic O
# , O
# delicious O
# and O
# very O
# , O
# very O
# affordable O
# . O
#
# Mmm O
# ... O
# good O
# ! O
#
# But O
# $ O
# 500 O
# for O
# a O
# dinner O
# for O
# two O
# that O
# didn't O
# include O
# Wine O
# ? O
#
# The O
# staff O
# offers O
# impeccable O
# service O
# . O
#
# Great O
# Indian O
# Food O
# ! O
#
# – O
# As O
# with O
# most O
# restaurants O
# in O
# Seattle O
# , O
# Mioposto's O
# service O
# was O
# bad O
# and O
# the O
# food O
# was O
# overpriced O
# . O
#
# Great O
# draft O
# and O
# bottle O
# selection O
# and O
# the O
# pizza O
# rocks O
# . O
#
# We O
# went O
# to O
# Ino O
# for O
# Valentines O
# . O
#
# The O
# wait O
# staff O
# is O
# pleasant O
# , O
# fun O
# , O
# and O
# for O
# the O
# most O
# part O
# gorgeous O
# ( O
# in O
# the O
# wonderful O
# aesthetic O
# beautification O
# way O
# , O
# not O
# in O
# that O
# she's-way-cuter-than-me-that-b O
# @ O
# # O
# $ O
# * O
# way O
# ) O
# . O
#
# There O
# is O
# something O
# about O
# their O
# atmosphere O
# that O
# makes O
# me O
# come O
# back O
# nearly O
# every O
# week O
# . O
#
# The O
# last O
# two O
# times O
# I O
# ordered O
# from O
# here O
# my O
# food O
# was O
# soo O
# spicy O
# that O
# I O
# could O
# barely O
# eat O
# it O
# , O
# and O
# the O
# spice O
# took O
# away O
# from O
# the O
# flavor O
# of O
# the O
# dish O
# . O
#
# Quite O
# frankly O
# , O
# this O
# is O
# some O
# of O
# the O
# worst O
# sushi O
# I O
# have O
# ever O
# tried O
# . O
#
# If O
# I O
# could O
# give O
# 0 O
# stars O
# I O
# would O
# do O
# so O
# for O
# this O
# place O
# . O
#
# I O
# have O
# never O
# before O
# eaten O
# 40 O
# pieces O
# of O
# relatively O
# good O
# nigiri O
# . O
#
# When O
# family O
# came O
# in O
# he O
# gave O
# them O
# apps O
# to O
# test O
# their O
# palets O
# , O
# and O
# then O
# ordered O
# for O
# them O
# . O
#
# With O
# the O
# exception O
# of O
# our O
# lemon O
# salad O
# that O
# had O
# so O
# much O
# pepper O
# on O
# it O
# that O
# our O
# eyes O
# started O
# watering O
# , O
# the O
# food O
# here O
# was O
# decent O
# , O
# not O
# great O
# . O
#
# What O
# a O
# great O
# place O
# . O
#
# My O
# friend O
# is O
# 100 O
# % O
# right O
# in O
# the O
# experience O
# we O
# had O
# . O
#
# The O
# rest O
# of O
# the O
# dim O
# sum O
# , O
# though O
# pricey O
# by O
# Chinatown O
# standards O
# , O
# is O
# worth O
# it O
# . O
#
# Much O
# of O
# the O
# time O
# it O
# seems O
# like O
# they O
# do O
# not O
# care O
# about O
# you O
# . O
#
# Best O
# In O
# ALL O
# of O
# NYC O
#
# Trust O
# me O
# . O
#
# And O
# where O
# does O
# Patis O
# go O
# wrong O
# ; O
# no O
# where O
# . O
#
# This O
# is O
# undoubtedly O
# my O
# favorite O
# modern O
# Japanese O
# brasserie O
# ( O
# that O
# don O
# ’ O
# t O
# serve O
# sushi O
# ) O
# , O
# and O
# in O
# my O
# opinion O
# , O
# one O
# of O
# the O
# most O
# romantic O
# restaurants O
# in O
# the O
# city O
# ! O
#
# My O
# husband O
# said O
# he O
# could've O
# eaten O
# several O
# more O
# , O
# the O
# portion O
# was O
# fine O
# for O
# me O
# he O
# even O
# exclaimed O
# that O
# the O
# french O
# fries O
# were O
# the O
# best O
# he O
# has O
# had O
# . O
#
# We O
# asked O
# for O
# sides O
# which O
# the O
# waiter O
# than O
# admitted O
# that O
# he O
# forgot O
# to O
# put O
# in O
# that O
# part O
# of O
# our O
# order O
# . O
#
# I O
# am O
# bringing O
# my O
# whole O
# family O
# back O
# next O
# time O
# . O
#
# These O
# are O
# overpriced O
# and O
# you O
# can O
# get O
# better O
# just O
# around O
# the O
# corner O
# : O
#
# After O
# dinner O
# the O
# manager O
# grabbed O
# my O
# boyfriend O
# , O
# asked O
# him O
# : O
# Where O
# are O
# you O
# from O
# ... O
# maybe O
# you O
# dont O
# know O
# how O
# things O
# work O
# in O
# America O
# ... O
# and O
# in O
# the O
# end O
# stormed O
# away O
# almost O
# teareyed O
# yelling O
# that O
# tips O
# are O
# the O
# only O
# thing O
# they O
# survive O
# on O
# . O
#
# It O
# was O
# well O
# worth O
# the O
# wait O
# . O
#
# My O
# husband O
# and O
# I O
# thougt O
# it O
# would O
# be O
# great O
# to O
# go O
# to O
# the O
# Jekyll O
# and O
# Hyde O
# Pub O
# for O
# our O
# anniversary O
# , O
# and O
# to O
# our O
# surprise O
# it O
# was O
# fantastic O
# . O
#
# ERRORI O
# stumbled O
# upon O
# this O
# great O
# pizzeria O
# as O
# I O
# explored O
# my O
# new O
# neighborhood O
# . O
#
# It O
# ? O
# s O
# served O
# with O
# either O
# a O
# peppercorn O
# sauce O
# or O
# red O
# wine O
# reduction O
# , O
# though O
# both O
# were O
# indistinguishable O
# in O
# taste O
# . O
#
# The O
# food O
# was O
# absolutely O
# amazing O
# ! O
# ! O
#
# We O
# put O
# out O
# name O
# down O
# and O
# although O
# there O
# were O
# open O
# tables O
# we O
# were O
# told O
# that O
# it'd O
# be O
# a O
# 30 O
# minute O
# wait O
# . O
#
# I O
# do O
# not O
# think O
# dinner O
# in O
# Manhattan O
# should O
# cost O
# $ O
# 400.00 O
# where O
# I O
# am O
# not O
# swept O
# off O
# my O
# feet O
# . O
#
# ERRORi O
# actually O
# feel O
# like O
# i O
# should O
# keep O
# it O
# a O
# secret O
# . O
#
# Very O
# disappointed O
# . O
#
# ERRORRather O
# than O
# preparing O
# vegetarian O
# dish O
# , O
# the O
# chef O
# presented O
# me O
# with O
# a O
# plate O
# of O
# steamed O
# vegetables O
# ( O
# minus O
# sauce O
# , O
# seasoning O
# , O
# or O
# any O
# form O
# or O
# aesthetic O
# presentation O
# ) O
# . O
#
# In O
# the O
# end O
# you O
# end O
# up O
# with O
# a O
# fair O
# tab O
# and O
# NOTHING O
# BUT O
# A O
# GREAT O
# TIME O
# ! O
# ! O
# ! O
#
# – O
# I O
# am O
# exceedingly O
# pleased O
# to O
# report O
# that O
# my O
# dinner O
# at O
# Ray's O
# Boathouse O
# last O
# Friday O
# completely O
# exceeded O
# my O
# expectations O
# . O
#
# She O
# was O
# very O
# helpful O
# in O
# suggesting O
# us O
# drinks O
# and O
# helped O
# us O
# in O
# ordering O
# a O
# lot O
# of O
# good O
# dishes O
# since O
# we O
# knew O
# nothing O
# about O
# Indian O
# food O
# . O
#
# Went O
# here O
# on O
# a O
# friend's O
# reccomendation O
# . O
#
# I O
# know O
# many O
# people O
# have O
# their O
# favorite O
# types O
# of O
# pizza O
# and O
# pizza O
# places O
# , O
# but O
# Mioposto's O
# pizza O
# lacks O
# quality O
# and O
# good O
# taste O
# . O
#
# I O
# went O
# there O
# for O
# lunch O
# and O
# it O
# was O
# not O
# as O
# good O
# as O
# I O
# expected O
# from O
# the O
# reviews O
# I O
# read O
# . O
#
# What O
# a O
# hassle O
# ! O
#
# This O
# place O
# must O
# have O
# cost O
# the O
# owners O
# afortune O
# to O
# build O
# . O
#
# On O
# the O
# way O
# out O
# , O
# we O
# heard O
# of O
# other O
# guests O
# complaining O
# about O
# similar O
# issues O
# . O
#
# ERRORWe O
# all O
# felt O
# it O
# was O
# worth O
# it O
# . O
#
# Love O
# their O
# drink O
# menu O
# . O
#
# If O
# you O
# are O
# going O
# for O
# the O
# food O
# , O
# it O
# will O
# not O
# be O
# worth O
# it O
# . O
#
# ERRORIts O
# worth O
# the O
# wait O
# , O
# especially O
# since O
# they'll O
# give O
# you O
# a O
# call O
# when O
# the O
# table O
# is O
# ready O
# . O
#
# i O
# went O
# to O
# utsav O
# about O
# a O
# yr O
# ago O
# with O
# my O
# family O
# . O
#
# ERROROne O
# would O
# think O
# we'd O
# get O
# an O
# apology O
# or O
# complimentary O
# drinks O
# - O
# instead O
# , O
# we O
# got O
# a O
# snobby O
# waiter O
# wouldn't O
# even O
# take O
# our O
# order O
# for O
# 15 O
# minutes O
# and O
# gave O
# us O
# lip O
# when O
# we O
# asked O
# him O
# to O
# do O
# so O
# . O
#
# After O
# sitting O
# at O
# the O
# bar O
# for O
# over O
# 20 O
# minutes O
# the O
# bar O
# keep O
# had O
# made O
# only O
# 2 O
# drinks O
# & O
# kept O
# telling O
# us O
# she'd O
# be O
# right O
# with O
# us O
# . O
#
# The O
# frizzy O
# retro O
# girl O
# ( O
# with O
# winged O
# / O
# Dame O
# Edna O
# glasses O
# ) O
# will O
# yell O
# at O
# you O
# if O
# you O
# try O
# to O
# order O
# a O
# drink O
# . O
#
# If O
# it's O
# nice O
# outside O
# , O
# request O
# for O
# a O
# table O
# in O
# the O
# balcony O
# . O
#
# Dokebi O
# gives O
# Williamsburg O
# the O
# right O
# one-two O
# punch O
# of O
# classic O
# Korean O
# food O
# and O
# fusion O
# twists O
# like O
# pork O
# belly O
# tacos O
# . O
#
# It O
# is O
# also O
# extremely O
# well O
# priced O
# . O
#
# this O
# place O
# ... O
# we O
# stumbled O
# upon O
# it O
# on O
# labor O
# day O
# weekend O
# . O
#
# Went O
# on O
# a O
# 3 O
# day O
# oyster O
# binge O
# , O
# with O
# Fish O
# bringing O
# up O
# the O
# closing O
# , O
# and O
# I O
# am O
# so O
# glad O
# this O
# was O
# the O
# place O
# it O
# O O
# trip O
# ended O
# , O
# because O
# it O
# was O
# so O
# great O
# ! O
#
# Next O
# time O
# we O
# will O
# go O
# somewhere O
# else O
# , O
# or O
# try O
# other O
# restaurants O
# close O
# by O
# like O
# Mimi's O
# Cafe O
# and O
# Claim O
# Jumper O
# . O
#
# The O
# drinks O
# are O
# great O
# , O
# especially O
# when O
# made O
# by O
# Raymond O
# . O
#
# Most O
# importantly O
# , O
# food O
# is O
# excellent O
# . O
#
# The O
# service O
# is O
# awful O
# . O
#
# The O
# food O
# is O
# a O
# diamond O
# in O
# rough O
# - O
# - O
# the O
# food O
# is O
# delicious O
# and O
# homemade O
# with O
# the O
# perfect O
# balance O
# of O
# herbs O
# and O
# tomatoes O
# . O
#
# ERRORIf O
# there O
# is O
# a O
# line O
# very O
# day O
# of O
# the O
# week O
# for O
# the O
# entire O
# time O
# a O
# place O
# is O
# open O
# , O
# you O
# know O
# it O
# is O
# great O
# . O
#
# Everyone O
# seemed O
# generally O
# happy O
# with O
# their O
# food O
# , O
# except O
# my O
# brother O
# who O
# had O
# the O
# grilled O
# Mahi O
# Mahi O
# , O
# seemingly O
# drenched O
# in O
# Grapfruit O
# Juice O
# ! O
#
# The O
# bathroom O
# itself O
# is O
# very O
# small O
# with O
# two O
# toilets O
# and O
# only O
# one O
# sink O
# , O
# the O
# girl O
# was O
# staying O
# totally O
# on O
# the O
# way O
# hanging O
# out O
# paper O
# towels O
# from O
# the O
# dispenser O
# . O
#
# – O
# Schooner O
# or O
# Later's O
# charming O
# location O
# along O
# the O
# marina O
# in O
# Long O
# Beach O
# and O
# average O
# food O
# does O
# not O
# , O
# unfortunately O
# , O
# compensate O
# for O
# its O
# very O
# poor O
# customer O
# service O
# . O
#
# ERRORThe O
# restaurant O
# was O
# packed O
# at O
# first O
# , O
# so O
# we O
# waited O
# at O
# the O
# bar O
# for O
# about O
# 20 O
# minutes O
# before O
# we O
# were O
# seated O
# . O
#
# For O
# a O
# Fabulous O
# Wedding O
# ! O
#
# ERRORAgain O
# , O
# no O
# apology O
# , O
# no O
# is O
# there O
# anything O
# else O
# I O
# can O
# get O
# you O
# , O
# no O
# can O
# I O
# get O
# you O
# a O
# drink O
# to O
# make O
# up O
# for O
# it O
# , O
# nothing O
# ! O
# ! O
# ! O
#
# Visited O
# there O
# while O
# on O
# vacation O
# and O
# reading O
# the O
# reviews O
# . O
#
# A O
# must O
# try O
# ! O
#
# DONOT O
# GO O
# ! O
#
# This O
# is O
# a O
# wonderful O
# place O
# on O
# all O
# stand O
# points O
# especially O
# value O
# ofr O
# money O
# . O
#
# Worth O
# the O
# wait O
#
# I've O
# been O
# many O
# time O
# and O
# have O
# never O
# been O
# disappointed O
# . O
#
# ERRORWe O
# were O
# fast O
# to O
# order O
# the O
# appetizer O
# platter O
# since O
# we O
# were O
# very O
# hungry O
# . O
#
# I O
# also O
# recommend O
# the O
# rice O
# dishes O
# or O
# the O
# different O
# varieties O
# of O
# congee O
# ( O
# rice O
# porridge O
# ) O
# . O
#
# The O
# food O
# is O
# sinful O
# . O
#
# A O
# real O
# dissapointment O
# . O
#
# Love O
# Al O
# Di O
# La O
#
# ERRORI O
# highly O
# recommend O
# it O
# . O
#
# Their O
# calzones O
# are O
# horrific O
# , O
# bad O
# , O
# vomit-inducing O
# , O
# YUCK O
# . O
#
# I O
# thanked O
# my O
# friend O
# who O
# recommended O
# me O
# this O
# restaurant O
# and O
# will O
# certainly O
# recommend O
# it O
# to O
# others O
# . O
#
# Sometimes O
# you O
# pay O
# a O
# lot O
# and O
# don't O
# get O
# much O
# in O
# return O
# - O
# it's O
# manhattan O
# , O
# things O
# are O
# expensive O
# . O
#
# The O
# service O
# was O
# courteous O
# and O
# attentive O
# . O
#
# Great O
# food O
# and O
# the O
# prices O
# are O
# very O
# reasonable O
# . O
#
# There O
# are O
# no O
# negatives O
# to O
# speak O
# of O
# . O
#
# The O
# duck O
# confit O
# is O
# always O
# amazing O
# and O
# the O
# foie O
# gras O
# terrine O
# with O
# figs O
# was O
# out O
# of O
# this O
# world O
# . O
#
# I O
# love O
# Dungeness O
# crabs O
# and O
# at O
# Ray's O
# you O
# can O
# get O
# them O
# served O
# in O
# about O
# 6 O
# different O
# ways O
# ! O
#
# I O
# probably O
# wouldn't O
# go O
# back O
# though O
# ' O
# cuz O
# I O
# don't O
# know O
# if O
# it's O
# worth O
# it O
# . O
#
# ERRORI O
# have O
# reservations O
# about O
# the O
# all O
# you O
# can O
# eat O
# deal O
# , O
# however O
# - O
# - O
# the O
# choices O
# are O
# fairly O
# limited O
# and O
# you O
# can O
# probably O
# order O
# more O
# food O
# than O
# you O
# can O
# eat O
# for O
# less O
# than O
# $ O
# 18 O
# by O
# just O
# going O
# off O
# the O
# menu O
# . O
#
# ERRORThis O
# establishment O
# really O
# made O
# a O
# marked O
# decline O
# after O
# ( O
# and O
# this O
# is O
# recurring O
# story O
# ) O
# the O
# airing O
# of O
# FOOD O
# TELEVISIONS O
# " O
# DINERS O
# , O
# DRIVE-INS O
# , O
# AND O
# DIVES O
# " O
# hosted O
# by O
# Guy O
# Fieri O
# , O
# in O
# which O
# Schooner O
# or O
# Later O
# was O
# subject O
# of O
# . O
#
# As O
# a O
# Japanese O
# native O
# , O
# I've O
# lived O
# in O
# the O
# Tristate O
# area O
# for O
# over O
# 8 O
# years O
# , O
# but O
# I O
# was O
# just O
# so O
# amazed O
# at O
# this O
# place O
# . O
#
# For O
# the O
# people O
# who O
# want O
# great O
# food O
# plus O
# great O
# service O
# , O
# Roxy O
# is O
# a O
# place O
# to O
# AVOID O
# ! O
#
# please O
# don't O
# fool O
# us O
# . O
#
# Hands O
# down O
# , O
# the O
# best O
# tuna O
# I O
# have O
# ever O
# had O
# . O
#
# ERRORTold O
# us O
# to O
# sit O
# anywhere O
# , O
# and O
# when O
# we O
# sat O
# he O
# said O
# the O
# table O
# was O
# reserved O
# . O
#
# Amazing O
# ! O
#
# I O
# know O
# because O
# I O
# live O
# nearby O
# . O
#
# ERRORERRORIt O
# was O
# one O
# of O
# the O
# few O
# places O
# in O
# SoCal O
# where O
# you O
# would O
# actually O
# walk O
# around O
# and O
# not O
# have O
# to O
# take O
# a O
# car O
# . O
#
# Outside O
# in O
# the O
# area O
# between O
# the O
# restaurant O
# and O
# the O
# park O
# , O
# children O
# were O
# running O
# around O
# while O
# their O
# parents O
# sipped O
# wine O
# . O
#
# I O
# took O
# one O
# look O
# at O
# the O
# chicken O
# and O
# I O
# was O
# appalled O
# . O
#
# Great O
# survice O
#
# fresh O
# restaurant O
# was O
# amazing O
# ... O
# food O
# was O
# delicious O
# and O
# of O
# course O
# fresh O
# . O
#
# I O
# cannot O
# imagine O
# you O
# not O
# rushing O
# out O
# to O
# eat O
# there O
# . O
#
# Even O
# after O
# they O
# overcharged O
# me O
# the O
# last O
# time O
# I O
# was O
# there O
# . O
#
# We O
# did O
# arrive O
# late O
# for O
# our O
# reservation O
# so O
# I O
# can O
# not O
# complain O
# too O
# much O
# about O
# the O
# wait O
# for O
# a O
# table O
# . O
#
# I O
# have O
# been O
# twice O
# to O
# this O
# restaurant O
# . O
#
# The O
# mussels O
# were O
# fantastic O
# and O
# so O
# was O
# the O
# dessert O
# ... O
# definitely O
# going O
# to O
# be O
# back O
# very O
# soon O
# . O
#
# Yes O
# , O
# I O
# ate O
# the O
# food O
# , O
# but O
# I O
# certainly O
# would O
# not O
# have O
# if O
# I O
# had O
# seen O
# the O
# maggot O
# before O
# eating O
# , O
# and O
# I O
# was O
# at O
# this O
# point O
# fairly O
# sick O
# to O
# my O
# stomach O
# . O
#
# The O
# place O
# was O
# nice O
# and O
# calm O
# . O
#
# I O
# have O
# it O
# a O
# 4 O
# instead O
# of O
# 5 O
# because O
# of O
# the O
# price O
# ( O
# just O
# chicken O
# tikka O
# masala O
# - O
# no O
# bread O
# of O
# rice O
# - O
# is O
# $ O
# 25 O
# ) O
# , O
# which O
# I O
# would O
# expect O
# at O
# a O
# upscale O
# Indian O
# restaurant O
# but O
# this O
# place O
# doesn't O
# have O
# an O
# upscale O
# feel O
# . O
#
# ERRORBut O
# for O
# the O
# Shabu O
# Shabu O
# , O
# you O
# won't O
# find O
# much O
# better O
# in O
# NY O
# . O
#
# As O
# a O
# student O
# in O
# NYU O
# i O
# need O
# a O
# place O
# to O
# eat O
# after O
# a O
# hard O
# day O
# of O
# work O
# so O
# usually O
# i O
# just O
# go O
# to O
# any O
# indian O
# restraunt O
# near O
# by O
# . O
#
# ERRORI O
# wish O
# I O
# COULD O
# be O
# refunded O
# ! O
#
# This O
# establishment O
# is O
# consistent O
# with O
# my O
# feelings O
# of O
# the O
# rest O
# of O
# Chow O
# Foods O
# group O
# . O
#
# Rao's O
# has O
# the O
# best O
# service O
# and O
# atmosphere O
# in O
# NYC O
# . O
#
# For O
# each O
# course O
# we O
# waited O
# over O
# 1/2 O
# hour O
# to O
# 45 O
# minutes O
# and O
# were O
# never O
# offered O
# a O
# drink O
# . O
#
# Considering O
# you O
# will O
# spend O
# at O
# least O
# $ O
# 60 O
# a O
# head O
# , O
# I O
# expect O
# better O
# service O
# . O
#
# This O
# is O
# the O
# perfect O
# spot O
# for O
# meeting O
# friends O
# , O
# having O
# lunch O
# , O
# dinner O
# , O
# pre-theatre O
# or O
# after-theatre O
# drinks O
# ! O
#
# There's O
# nice O
# and O
# quiet O
# , O
# small O
# but O
# enough O
# for O
# 6 O
# ( O
# or O
# more O
# ) O
# . O
#
# Not O
# only O
# is O
# it O
# an O
# adventure O
# getting O
# to O
# this O
# somewhat O
# hidden O
# spot O
# , O
# once O
# you O
# enter O
# the O
# unmarked O
# wooden O
# doors O
# , O
# the O
# zen O
# and O
# intimate O
# décor O
# will O
# make O
# you O
# feel O
# like O
# you O
# ’ O
# re O
# no O
# longer O
# in O
# the O
# city O
# . O
#
# Even O
# though O
# the O
# place O
# is O
# not O
# beautiful O
# , O
# the O
# food O
# speaks O
# for O
# itself O
# . O
#
# The O
# cream O
# cheeses O
# are O
# out O
# of O
# this O
# world O
# and O
# I O
# love O
# that O
# coffee O
# ! O
# ! O
#
# Try O
# it O
# ! O
#
# This O
# was O
# a O
# repeat O
# visit O
# and O
# we'll O
# definitely O
# be O
# back O
# again O
# . O
#
# My O
# Girlfriend O
# and O
# I O
# stumbled O
# onto O
# this O
# hopping O
# place O
# the O
# other O
# night O
# and O
# had O
# a O
# great O
# time O
# ! O
#
# Indoor O
# was O
# very O
# cozy O
# and O
# cute O
# . O
#
# The O
# atmosphere O
# is O
# noisy O
# and O
# the O
# waiters O
# are O
# literally O
# walking O
# around O
# doing O
# things O
# as O
# fast O
# as O
# they O
# can O
# . O
#
# Best O
# Pastrami O
# I O
# ever O
# had O
# and O
# great O
# portion O
# without O
# being O
# ridiculous O
# . O
#
# The O
# Cypriot O
# restaurant O
# has O
# a O
# lot O
# going O
# for O
# it O
# . O
#
# ERRORThe O
# two O
# star O
# chefs O
# left O
# quite O
# some O
# time O
# ago O
# to O
# open O
# their O
# own O
# place O
# . O
#
# A O
# cool O
# bar O
# with O
# great O
# food O
# , O
# and O
# tons O
# of O
# excellent O
# beer O
# . O
#
# She O
# lives O
# nearby O
# but O
# had O
# never O
# gone O
# to O
# this O
# establishment O
# thinking O
# that O
# it O
# might O
# be O
# too O
# touristy O
# . O
#
# The O
# menu O
# is O
# very O
# limited O
# - O
# i O
# think O
# we O
# counted O
# 4 O
# or O
# 5 O
# entrees O
# . O
#
# In O
# fact O
# , O
# it O
# appears O
# he O
# is O
# going O
# to O
# go O
# postal O
# at O
# any O
# moment O
# . O
#
# Guaranteed O
# to O
# be O
# a O
# tasty O
# experience O
# ! O
# ) O
#
# A O
# little O
# pricey O
# but O
# it O
# really O
# hits O
# the O
# spot O
# on O
# a O
# Sunday O
# morning O
# ! O
#
# My O
# roommate O
# and O
# I O
# LOVE O
# this O
# place O
# . O
#
# I O
# have O
# a O
# but O
# here O
# - O
# there O
# was O
# a O
# bathroom O
# attendant O
# in O
# the O
# restroom O
# which O
# was O
# odd O
# . O
#
# The O
# hot O
# dogs O
# are O
# good O
# , O
# yes O
# , O
# but O
# the O
# reason O
# to O
# get O
# over O
# here O
# is O
# the O
# fantastic O
# pork O
# croquette O
# sandwich O
# , O
# perfect O
# on O
# its O
# supermarket O
# squishy O
# bun O
# . O
#
# It O
# was O
# clear O
# he O
# didn O
# ’ O
# t O
# really O
# care O
# . O
#
# I O
# thought O
# I O
# had O
# died O
# and O
# gone O
# to O
# heaven O
# . O
#
# The O
# food O
# is O
# prepared O
# quickly O
# and O
# efficiently O
# . O
#
# This O
# place O
# has O
# the O
# best O
# Chinese O
# style O
# BBQ O
# ribs O
# in O
# the O
# city O
# . O
#
# I O
# recommend O
# it O
# for O
# a O
# night O
# when O
# you O
# want O
# to O
# splurge O
# ! O
# ( O
# it O
# was O
# a O
# bit O
# expensive O
# ) O
#
# We O
# were O
# then O
# shooed O
# inside O
# . O
#
# I O
# never O
# heard O
# back O
# from O
# anyone O
# more O
# than O
# a O
# month O
# ago O
# . O
#
# We O
# got O
# a O
# little O
# tipsy O
# from O
# the O
# sake O
# but O
# isn't O
# that O
# what O
# Saturday O
# nights O
# with O
# the O
# girlfriends O
# are O
# all O
# about O
# ? O
#
# A O
# restaurant O
# that O
# doesn't O
# try O
# to O
# do O
# anything O
# except O
# serve O
# great O
# food O
# with O
# great O
# service O
# in O
# a O
# pleasant O
# atmosphere O
# . O
#
# In O
# short O
# , O
# Schooner O
# or O
# Later O
# couldn't O
# have O
# cared O
# less O
# about O
# our O
# being O
# at O
# their O
# establishment O
# . O
#
# As O
# usual O
# the O
# omikase O
# didn't O
# disappoint O
# in O
# freshness O
# , O
# although O
# it O
# scored O
# low O
# on O
# creativity O
# and O
# selection O
# . O
#
# I O
# stumbled O
# upon O
# this O
# second O
# floor O
# walk-up O
# two O
# Fridays O
# ago O
# when O
# I O
# was O
# with O
# two O
# friends O
# in O
# town O
# from O
# L O
# . O
# A O
# . O
#
# I O
# think O
# I've O
# had O
# some O
# the O
# best O
# meals O
# of O
# my O
# life O
# at O
# minnow O
# . O
#
# – O
# Great O
# financial O
# district O
# mexican O
# spot O
# . O
#
# I'll O
# keep O
# this O
# short O
# . O
#
# AMAZING O
# MY O
# FAVORITE O
# ! O
# ! O
# ! O
#
# I'd O
# hate O
# for O
# tourists O
# to O
# go O
# to O
# Park O
# Chalet O
# and O
# think O
# that O
# this O
# is O
# how O
# all O
# San O
# Francisco O
# restaurants O
# are O
# like O
# . O
#
# I O
# got O
# hair O
# in O
# my O
# food O
# 2 O
# times O
# of O
# then O
# ! O
#
# Great O
# bagels O
# , O
# spreads O
# and O
# a O
# good O
# place O
# to O
# hang O
# out O
# in O
# . O
#
# My O
# six O
# year O
# old O
# loved O
# it O
# . O
#
# It's O
# very O
# spicy O
# but O
# not O
# offensive O
# . O
#
# I O
# had O
# Filet O
# Mignon O
# with O
# garlic O
# mash O
# . O
#
# Friendly O
# staff O
# that O
# actually O
# lets O
# you O
# enjoy O
# your O
# meal O
# and O
# the O
# company O
# you're O
# with O
# . O
#
# The O
# pizza O
# is O
# overpriced O
# and O
# soggy O
# . O
#
# You O
# Can't O
# Go O
# Wrong O
# Here O
# . O
#
# I O
# ended O
# the O
# meal O
# with O
# the O
# unusual O
# dessert O
# of O
# a O
# port O
# and O
# chocolate O
# tasting O
# ... O
# yummy O
# ! O
#
# But O
# the O
# best O
# pork O
# souvlaki O
# I O
# ever O
# had O
# is O
# the O
# main O
# thing O
# . O
#
# ERRORI O
# am O
# reluctant O
# to O
# write O
# because O
# I O
# would O
# not O
# want O
# my O
# jem O
# of O
# a O
# pizza O
# place O
# to O
# become O
# overcrowded O
# . O
#
# To O
# be O
# completely O
# fair O
# , O
# the O
# only O
# redeeming O
# factor O
# was O
# the O
# food O
# , O
# which O
# was O
# above O
# average O
# , O
# but O
# couldn't O
# make O
# up O
# for O
# all O
# the O
# other O
# deficiencies O
# of O
# Teodora O
# . O
#
# Terrible O
# service O
# , O
# food O
# ok O
# , O
# pricey O
#
# The O
# place O
# is O
# so O
# cool O
# and O
# the O
# service O
# is O
# prompt O
# and O
# curtious O
# . O
#
# This O
# is O
# the O
# kind O
# of O
# place O
# you'd O
# like O
# to O
# take O
# all O
# your O
# friends O
# to O
# and O
# still O
# keep O
# a O
# secret O
# . O
#
# – O
# A O
# group O
# of O
# 5 O
# of O
# us O
# went O
# there O
# for O
# Sunday O
# brunch O
# and O
# sat O
# outside O
# . O
#
# The O
# food O
# was O
# actually O
# aweful O
# . O
#
# The O
# service O
# was O
# spectacular O
# as O
# the O
# waiter O
# knew O
# everything O
# about O
# the O
# menu O
# and O
# his O
# recommendations O
# were O
# amazing O
# ! O
#
# Other O
# guests O
# enjoyed O
# pizza O
# , O
# santa O
# fe O
# chopped O
# salad O
# and O
# fish O
# and O
# chips O
# . O
#
# I O
# had O
# the O
# kafta O
# plate O
# and O
# I O
# enjoyed O
# it O
# . O
#
# love O
# the O
# food O
# . O
#
# This O
# quaint O
# and O
# romantic O
# trattoria O
# is O
# at O
# the O
# top O
# of O
# my O
# Manhattan O
# restaurant O
# list O
# . O
#
# The O
# steak O
# was O
# done O
# to O
# my O
# exact O
# liking O
# ( O
# medium O
# rare O
# ) O
# and O
# was O
# nice O
# and O
# juicy O
# . O
#
# The O
# three O
# of O
# us O
# standing O
# in O
# front O
# of O
# her O
# should O
# have O
# been O
# an O
# indication O
# of O
# how O
# many O
# of O
# us O
# there O
# were O
# . O
#
# ERRORERRORHowever O
# , O
# it O
# is O
# jus O
# too O
# good O
# to O
# not O
# praise O
# it O
# . O
#
# We O
# got O
# most O
# of O
# it O
# back O
# at O
# home O
# with O
# us O
# . O
#
# This O
# is O
# by O
# far O
# my O
# favorite O
# place O
# in O
# the O
# neighborhood O
# . O
#
# Will O
# absolutely O
# visit O
# again O
# . O
#
# really O
# depends O
# on O
# your O
# luck O
# ! O
#
# There O
# is O
# only O
# one O
# place O
# on O
# the O
# east O
# coast O
# that O
# has O
# it O
# all O
# , O
# plus O
# a O
# lot O
# more O
# . O
#
# food O
# was O
# fine O
# , O
# with O
# a O
# some O
# little-tastier-than-normal O
# salsa O
# . O
#
# The O
# food O
# was O
# great O
# ! O
#
# Quick O
# and O
# friendly O
# service O
# . O
